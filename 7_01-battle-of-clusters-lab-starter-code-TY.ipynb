# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Comparing Clustering Algorithm Effectiveness
#
# _Authors: Tim Book (DC), Kiefer Katovich (SF)_
#
# ---
#
# In this lab, you'll test three of the clustering algorithms we've covered on seven data sets that are specifically designed to evaluate clustering algorithm effectiveness.
#
# This lab is exploratory and heavy on data visualization.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

plt.style.use('fivethirtyeight')

# %matplotlib inline

# %% [markdown]
# ---
#
# ### 1) Load the data sets.
#
# Each of the seven data sets have three columns:
#
#     x
#     y
#     label
#
# Because they each only have two variables, they're easy to examine visually. You’ll compare the “true” labels for the data to the clusters the algorithms find.

# %%
flame = pd.read_csv('./datasets/flame.csv')
agg = pd.read_csv('./datasets/aggregation.csv')
comp = pd.read_csv('./datasets/compound.csv')
jain = pd.read_csv('./datasets/jain.csv')
path = pd.read_csv('./datasets/pathbased.csv')
r15 = pd.read_csv('./datasets/r15.csv')
spiral = pd.read_csv('./datasets/spiral.csv')

# %% [markdown]
# ---
#
# ### 2) Plot each of the data sets with colored true labels.
#
# The data sets have different numbers of unique labels, so you'll need to figure out how many there are for each and color the clusters accordingly (for example, `r15` has 15 different clusters).
#
# You might find [this](https://matplotlib.org/examples/color/colormaps_reference.html) help page on colormaps useful!

# %%
flame.head()
# Out:
#       x      y  label
# 0  1.85  27.80      1
# 1  1.35  26.65      1
# 2  1.40  23.25      2
# 3  0.85  23.05      2
# 4  0.50  22.35      2

# %%
# Plotting function.
# Plotting function should take (df, name) as arguments. `name` will be the plot's title.

def plot_clusters(df, name):
    df.plot(kind='scatter', x='x', y='y', c='label', colormap='tab20c')
    plt.title(name, fontsize=20)

# %%
dfs = [
    (flame, 'flame'),
    (agg, 'agg'),
    (comp, 'comp'),
    (jain, 'jain'),
    (path, 'path'),
    (r15, 'r15'),
    (spiral, 'spiral')
]

# %%
# Plot each data set with the true cluster labels.
[plot_clusters(df, name) for df, name in dfs];

# %% [markdown]
# ---
#
# ### 3) Write a plotting function (or functions) to compare the performance of the three clustering algorithms.
#
# Load in the three clustering algorithms we covered earlier in the class.
#
#     K-means: k-means clustering.
#     Agglomerative clustering: hierarchical clustering (bottom up).
#     DBSCAN: density-based clustering.
#
# Your function(s) should allow you to visually examine the effects of changing different parameters in the clustering algorithms. The parameters you should explore, at minimum, are:
#
#     K-means:
#         n_clusters
#     Agglomerative clustering:
#         n_clusters
#     DBSCAN
#         eps
#         min_samples
#
# Feel free to explore other parameters for these models.

# %%
from sklearn.cluster import KMeans, AgglomerativeClustering, DBSCAN
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score

# %% [markdown]
# ### But first: Let's write a function that scales our data for us.
# Why do we need to scale our data for clustering algorithms? (thread)

# %%
# Write your function to scale data here.
def scale_matrix(X):
    sc = StandardScaler()
    return sc.fit_transform(X)

# %%
# Write a function that will plot the results of the three
# clustering algorithms for comparison.

# Your function should take TWO INPUTS:
# 1 - The data
# 2 - The clusterer

# Your function should do TWO THINGS:
# 1 - Print the SILHOUETTE SCORE for your clusters
# 2 - Plot the clusteres with appropriate coloring

def plot_results(df, cl):
    # Scale data
    X = df[['x', 'y']]
    X_sc = scale_matrix(X)
    # Fit clusterer
    cl.fit(X_sc) 
    df['cluster'] = cl.labels_
    # Print Silhouette Score
    sil = silhouette_score(X_sc, cl.labels_)
    print(f"Silhouette Sore: {sil}")
    # Plot
    df.plot(kind='scatter', x='x', y='y', c='cluster', colormap='tab20c')

# %% [markdown]
# ## 4) Tinkering with clustering parameters.
#
# In the following sections, look at how the parameters affect the clustering algorithms and try to get clusters that make sense. There is no right answer here, as these are unsupervised techniques.
#
# Don't forget to check out **silhouette scores!**

# %% [markdown]
# ### 4.A) Find good parameters for the `flame` data set.
#
# Which algorithm (visually) performs best?

# %%
# A:
cl = DBSCAN(eps=0.25, min_samples=3)
plot_results(flame, cl)
cl = KMeans(n_clusters=2)
plot_results(flame, cl)
cl = AgglomerativeClustering(n_clusters=2)
plot_results(flame, cl)
# Out:
# Silhouette Sore: 0.04824604093491784
# C:\Users\Razer\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Razer\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Silhouette Sore: 0.3736248417997557
# Silhouette Sore: 0.3524942517997597

# %% [markdown]
# ---
#
# ### 4.B) Find good parameters for the `agg` data set.
#
# Which algorithm (visually) performs best?

# %%
# A:
cl = DBSCAN(eps=0.25, min_samples=8)
plot_results(agg, cl)
cl = KMeans(n_clusters=7)
plot_results(agg, cl)
cl = AgglomerativeClustering(n_clusters=7)
plot_results(agg, cl)
# Out:
# Silhouette Sore: 0.37039256879370025
# C:\Users\Razer\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Razer\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=4.
#   warnings.warn(
# Silhouette Sore: 0.47189007462628374
# Silhouette Sore: 0.4456446500640389

# %% [markdown]
# ---
#
# ### 4.C) Find good parameters for the `comp` data set.
#
# Which algorithm (visually) performs best?

# %%
# A:
cl = DBSCAN(eps=0.15, min_samples=7)
plot_results(comp, cl)
cl = KMeans(n_clusters=6)
plot_results(comp, cl)
cl = AgglomerativeClustering(n_clusters=6)
plot_results(comp, cl)
# Out:
# Silhouette Sore: 0.014207353647747601
# C:\Users\Razer\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Razer\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# Silhouette Sore: 0.42723446127584747
# Silhouette Sore: 0.40553337601893963

# %% [markdown]
# ---
#
# ### 4.D) Find good parameters for the `jain` data set.
#
# Which algorithm (visually) performs best?

# %%
# A:
cl = DBSCAN(eps=0.25, min_samples=3)
plot_results(jain, cl)
cl = KMeans(n_clusters=2)
plot_results(jain, cl)
cl = AgglomerativeClustering(n_clusters=2)
plot_results(jain, cl)
# Out:
# Silhouette Sore: 0.28395751272053943
# C:\Users\Razer\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Razer\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# Silhouette Sore: 0.5044779516212523
# Silhouette Sore: 0.5042663862106481

# %% [markdown]
# ---
#
# ### 4.E) Find good parameters for the `pathbased` data set.
#
# Which algorithm (visually) performs best?

# %%
# A:
cl = DBSCAN(eps=0.15, min_samples=4)
plot_results(path, cl)
cl = KMeans(n_clusters=3)
plot_results(path, cl)
cl = AgglomerativeClustering(n_clusters=3)
plot_results(path, cl)
# Out:
# Silhouette Sore: -0.17369478716444808
# C:\Users\Razer\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Razer\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# Silhouette Sore: 0.5092065033223903
# Silhouette Sore: 0.5007977633074632

# %% [markdown]
# ---
#
# ### 4.F) Find good parameters for the `r15` data set.
#
# Which algorithm (visually) performs best?

# %%
# A:
cl = DBSCAN(eps=0.25, min_samples=16)
plot_results(r15, cl)
cl = KMeans(n_clusters=15)
plot_results(r15, cl)
cl = AgglomerativeClustering(n_clusters=15)
plot_results(r15, cl)
# Out:
# Silhouette Sore: 0.653006125666107
# C:\Users\Razer\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Razer\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
# Silhouette Sore: 0.7527351144186859
# Silhouette Sore: 0.7495032842997014

# %% [markdown]
# ---
#
# ### 4.G) Find good parameters for the `spiral` data set.
#
# Which algorithm (visually) performs best?

# %%
# A:
cl = DBSCAN(eps=0.25, min_samples=4)
plot_results(spiral, cl)
cl = KMeans(n_clusters=3)
plot_results(spiral, cl)
cl = AgglomerativeClustering(n_clusters=3)
plot_results(spiral, cl)
# Out:
# Silhouette Sore: -0.01777577306264797
# C:\Users\Razer\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Razer\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# Silhouette Sore: 0.36039419815296814
# Silhouette Sore: 0.3277786301059895

# %% [markdown]
# ## 5) Melbourne Housing
# Data come from [this](https://www.kaggle.com/anthonypino/melbourne-housing-market) Kaggle page.

# %%
mel = pd.read_csv('datasets/melbourne.csv')
mel.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/09/2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  4/02/2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
#    YearBuilt         CouncilArea Lattitude  Longtitude             Regionname  \
# 0        NaN  Yarra City Council  -37.8014    144.9958  Northern Metropolitan
# 1        NaN  Yarra City Council  -37.7996    144.9984  Northern Metropolitan
# 2     1900.0  Yarra City Council  -37.8079    144.9934  Northern Metropolitan
# 3        NaN  Yarra City Council  -37.8114    145.0116  Northern Metropolitan
# 4     1900.0  Yarra City Council  -37.8093    144.9944  Northern Metropolitan
#
#   Propertycount
# 0        4019.0
# 1        4019.0
# 2        4019.0
# 3        4019.0
# 4        4019.0
#
# [5 rows x 21 columns]

# %% [markdown]
# ### 5a) Fix bad variable names
# We're only going to look at three variables here, and two of them are spelled wrong! Change the lat/long column names to either be spelled correctly or abbrevited as `lat`/`long`. While we're add it, let's change `Price` --> `price`.

# %%
mel.rename(columns={'Longtitude': 'long', 'Lattitude': 'lat', 'Price': 'price'}, inplace = True)
mel.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'lat', 'long',
#        'Regionname', 'Propertycount'],
#       dtype='object')

# %% [markdown]
# ### 5b) Drop missings
# Drop all rows where either `lat`, `long`, or `price` is missing.

# %%
mel = mel[mel.lat.notnull() & mel.long.notnull() & mel.price.notnull()]
mel.isna().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# price                0
# Method               0
# SellerG              0
# Date                 0
# Distance             0
# Postcode             0
# Bedroom2           209
# Bathroom           215
# Car                592
# Landsize          3033
# BuildingArea     10346
# YearBuilt         8917
# CouncilArea          0
# lat                  0
# long                 0
# Regionname           0
# Propertycount        0
# dtype: int64

# %% [markdown]
# ### 5c) Plot lat vs long
# What kind of clustering do you want to do?

# %%
mel.plot(kind='scatter', x='long', y='lat', s=1, figsize=(10, 10));

# %% [markdown]
# ### 5d) Prepare X matrix by scaling
# Why do we need to scale? (thread)

# %%
X = mel.loc[:, ['lat', 'long']]
X_sc= scale_matrix(X)

# %% [markdown]
# ### 5e) Cluster and plot clusters

# %%
km = KMeans(n_clusters=8)
km.fit(X_sc)
mel['cluster'] = km.labels_
# Out:
# C:\Users\Razer\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
mel.plot(
    kind='scatter',
    x='long',
    y='lat',
    c='cluster',
    colormap='Spectral',
    s=2,
    figsize=(8, 8)
)
# Out:
# <Axes: xlabel='long', ylabel='lat'>

# %% [markdown]
# ### 5f) Do prices differ by cluster?

# %%
mel.groupby('cluster').price.mean().plot(kind='bar')
# Out:
# <Axes: xlabel='cluster'>
