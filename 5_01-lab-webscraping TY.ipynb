# %%
# Import libaries
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# ### Step 1: Create a soup object from the home page

# %%
# URL of the homepage you want to scrape
url = "https://pages.git.generalassemb.ly/rldaggie/for-scraping/"

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the webpage
    soup = BeautifulSoup(response.content, "html.parser")
    
    # Find all the links on the page
    links = soup.find_all("a")
    
else:
    print("Failed to fetch the webpage")

# %% [markdown]
# ### Step 2: Scrape the home page soup for every restaurant
#
# Note: Your best bet is to create a list of dictionaries, one for each restaurant. Each dictionary contains the restaurant's name and path from the `href`. The result of your scrape should look something like this:
#
# ```python
# restaurants = [
#     {'name': 'A&W Restaurants', 'href': 'restaurants/1.html'},
#     {'name': "Applebee's", 'href': 'restaurants/2.html'},
#     ...
# ]
# ```

# %%
# Print the text and href attribute of each link
for link in links:
    link_text = link.text.strip()  # Get the text of the link
    link_href = link.get("href")   # Get the href attribute of the link
    print(f"Link Text: {link_text}, Href: {link_href}")
# Out:
# Link Text: Nutrition Information, Href: /
# Link Text: A&W Restaurants, Href: restaurants/1.html
# Link Text: Applebee's, Href: restaurants/2.html
# Link Text: Arby's, Href: restaurants/3.html
# Link Text: Atlanta Bread Company, Href: restaurants/4.html
# Link Text: Bojangle's Famous Chicken 'n Biscuits, Href: restaurants/5.html
# Link Text: Buffalo Wild Wings, Href: restaurants/6.html
# Link Text: Burger King, Href: restaurants/7.html
# Link Text: Captain D's, Href: restaurants/8.html
# Link Text: Carl's Jr., Href: restaurants/9.html
# Link Text: Charley's Grilled Subs, Href: restaurants/10.html
# Link Text: Chick-fil-A, Href: restaurants/11.html
# Link Text: Chili's, Href: restaurants/12.html
# Link Text: Chipotle Mexican Grill, Href: restaurants/13.html
# Link Text: Church's, Href: restaurants/14.html
# Link Text: Corner Bakery Cafe, Href: restaurants/15.html
# Link Text: Dairy Queen, Href: restaurants/16.html
# Link Text: Denny's, Href: restaurants/17.html
# Link Text: El Pollo Loco, Href: restaurants/18.html
# Link Text: FATZ, Href: restaurants/19.html
# Link Text: Fazoli's, Href: restaurants/20.html
# Link Text: Five Guys Burgers and Fries, Href: restaurants/21.html
# Link Text: Golden Chick, Href: restaurants/22.html
# Link Text: Hardee's, Href: restaurants/23.html
# Link Text: IHOP, Href: restaurants/24.html
# Link Text: In-N-Out Burger, Href: restaurants/25.html
# Link Text: Jack in the Box, Href: restaurants/26.html
# Link Text: Jimmy Johns, Href: restaurants/27.html
# Link Text: Joe's Crab Shack, Href: restaurants/28.html
# Link Text: KFC, Href: restaurants/29.html
# Link Text: McDonald's, Href: restaurants/30.html
# Link Text: O'Charley's, Href: restaurants/31.html
# Link Text: Olive Garden, Href: restaurants/32.html
# Link Text: Outback Steakhouse, Href: restaurants/33.html
# Link Text: Panda Express, Href: restaurants/34.html
# Link Text: Panera Bread, Href: restaurants/35.html
# Link Text: Popeye's, Href: restaurants/36.html
# Link Text: Quiznos, Href: restaurants/37.html
# Link Text: Red Robin Gourmet Burgers, Href: restaurants/38.html
# Link Text: Romano's Macaroni Grill, Href: restaurants/39.html
# Link Text: Ruby Tuesday, Href: restaurants/40.html
# Link Text: Subway, Href: restaurants/41.html
# Link Text: Taco Bell, Href: restaurants/42.html
# Link Text: Taco Bueno, Href: restaurants/43.html
# Link Text: Wendy's, Href: restaurants/44.html

# %%
# Remove first entry 
links_cleaned = links[1:]

# Create an empty list
restaurants = []

# Insert data into empty dictionary
for link in links_cleaned:
    # Create a dictionary to store the information of each link
    restaurant_info = {}
    # Get the text of the link and assign it to the 'name' key
    restaurant_info['name'] = link.text.strip()
    # Get the href attribute of the link and assign it to the 'href' key
    restaurant_info['href'] = link.get("href")
    # Add the restaurant information to the list
    restaurants.append(restaurant_info)

restaurants
# Out:
# [{'name': 'A&W Restaurants', 'href': 'restaurants/1.html'},
#  {'name': "Applebee's", 'href': 'restaurants/2.html'},
#  {'name': "Arby's", 'href': 'restaurants/3.html'},
#  {'name': 'Atlanta Bread Company', 'href': 'restaurants/4.html'},
#  {'name': "Bojangle's Famous Chicken 'n Biscuits",
#   'href': 'restaurants/5.html'},
#  {'name': 'Buffalo Wild Wings', 'href': 'restaurants/6.html'},
#  {'name': 'Burger King', 'href': 'restaurants/7.html'},
#  {'name': "Captain D's", 'href': 'restaurants/8.html'},
#  {'name': "Carl's Jr.", 'href': 'restaurants/9.html'},
#  {'name': "Charley's Grilled Subs", 'href': 'restaurants/10.html'},
#  {'name': 'Chick-fil-A', 'href': 'restaurants/11.html'},
#  {'name': "Chili's", 'href': 'restaurants/12.html'},
#  {'name': 'Chipotle Mexican Grill', 'href': 'restaurants/13.html'},
#  {'name': "Church's", 'href': 'restaurants/14.html'},
#  {'name': 'Corner Bakery Cafe', 'href': 'restaurants/15.html'},
#  {'name': 'Dairy Queen', 'href': 'restaurants/16.html'},
#  {'name': "Denny's", 'href': 'restaurants/17.html'},
#  {'name': 'El Pollo Loco', 'href': 'restaurants/18.html'},
#  {'name': 'FATZ', 'href': 'restaurants/19.html'},
#  {'name': "Fazoli's", 'href': 'restaurants/20.html'},
#  {'name': 'Five Guys Burgers and Fries', 'href': 'restaurants/21.html'},
#  {'name': 'Golden Chick', 'href': 'restaurants/22.html'},
#  {'name': "Hardee's", 'href': 'restaurants/23.html'},
#  {'name': 'IHOP', 'href': 'restaurants/24.html'},
#  {'name': 'In-N-Out Burger', 'href': 'restaurants/25.html'},
#  {'name': 'Jack in the Box', 'href': 'restaurants/26.html'},
#  {'name': 'Jimmy Johns', 'href': 'restaurants/27.html'},
#  {'name': "Joe's Crab Shack", 'href': 'restaurants/28.html'},
#  {'name': 'KFC', 'href': 'restaurants/29.html'},
#  {'name': "McDonald's", 'href': 'restaurants/30.html'},
#  {'name': "O'Charley's", 'href': 'restaurants/31.html'},
#  {'name': 'Olive Garden', 'href': 'restaurants/32.html'},
#  {'name': 'Outback Steakhouse', 'href': 'restaurants/33.html'},
#  {'name': 'Panda Express', 'href': 'restaurants/34.html'},
#  {'name': 'Panera Bread', 'href': 'restaurants/35.html'},
#  {'name': "Popeye's", 'href': 'restaurants/36.html'},
#  {'name': 'Quiznos', 'href': 'restaurants/37.html'},
#  {'name': 'Red Robin Gourmet Burgers', 'href': 'restaurants/38.html'},
#  {'name': "Romano's Macaroni Grill", 'href': 'restaurants/39.html'},
#  {'name': 'Ruby Tuesday', 'href': 'restaurants/40.html'},
#  {'name': 'Subway', 'href': 'restaurants/41.html'},
#  {'name': 'Taco Bell', 'href': 'restaurants/42.html'},
#  {'name': 'Taco Bueno', 'href': 'restaurants/43.html'},
#  {'name': "Wendy's", 'href': 'restaurants/44.html'}]

# %% [markdown]
# ### Step 3: Using the `href`, scrape each restaurant's page and create a single list of food dictionaries.
#
# Your list of foods should look something like this:
# ```python
# foods = [
#     {
#         'calories': '0',
#         'carbs': '0',
#         'category': 'Drinks',
#         'fat': '0',
#         'name': 'A&W® Diet Root Beer',
#         'restaurant': 'A&W Restaurants'
#     },
#     {
#         'calories': '0',
#         'carbs': '0',
#         'category': 'Drinks',
#         'fat': '0',
#         'name': 'A&W® Diet Root Beer',
#         'restaurant': 'A&W Restaurants'
#     },
#     ...
# ]
# ```
#
# **Note**: Remove extra white space from each category

# %%
# Create an empty list to store food information
foods = []

base_url = "https://pages.git.generalassemb.ly/rldaggie/for-scraping/"

for restaurant in restaurants:
    rest_url = base_url + restaurant['href']
    response = requests.get(rest_url)
    soup = BeautifulSoup(response.content, "html.parser")
    # Get data under 'td'
    menu = soup.find_all('td')
    for i in range(0, len(menu), 5):
        food_info = {}
        food_info['name'] = menu[i].text.strip()
        food_info['category'] = menu[i+1].text.strip()
        food_info['calories'] = menu[i+2].text.strip()
        food_info['fat'] = menu[i+3].text.strip()
        food_info['carbs'] = menu[i+4].text.strip()
        food_info['restaurant'] = restaurant['name']
        # Add the food information to the list
        print(food_info)
        foods.append(food_info)
# Out:
# {'name': 'Original Bacon Double Cheeseburger', 'category': 'Burgers', 'calories': '760', 'fat': '45', 'carbs': '45', 'restaurant': 'A&W Restaurants'}
# {'name': 'Coney (Chili) Dog', 'category': 'Entrees', 'calories': '340', 'fat': '20', 'carbs': '26', 'restaurant': 'A&W Restaurants'}
# {'name': 'Chili Fries', 'category': 'French Fries', 'calories': '370', 'fat': '15', 'carbs': '49', 'restaurant': 'A&W Restaurants'}
# {'name': 'Strawberry Milkshake (small)', 'category': 'Shakes', 'calories': '670', 'fat': '29', 'carbs': '90', 'restaurant': 'A&W Restaurants'}
# {'name': 'A&W® Root Beer Freeze (large)', 'category': 'Shakes', 'calories': '820', 'fat': '18', 'carbs': '150', 'restaurant': 'A&W Restaurants'}
# {'name': 'Caramel Sundae', 'category': 'Desserts', 'calories': '340', 'fat': '9', 'carbs': '57', 'restaurant': 'A&W Restaurants'}
# {'name': 'Strawberry Banana Smoothee', 'category': 'Shakes', 'calories': '420', 'fat': '6', 'carbs': '86', 'restaurant': 'A&W Restaurants'}
# {'name': 'Chocolate Fudge Blendrrr', 'category': 'Desserts', 'calories': '1010', 'fat': '59', 'carbs': '152', 'restaurant': 'A&W Restaurants'}
# {'name': 'Strawberry Limeade', 'category': 'Drinks', 'calories': '420', 'fat': '0', 'carbs': '105', 'restaurant': 'A&W Restaurants'}
# {'name': 'Watermelon Slushee', 'category': 'Drinks', 'calories': '270', 'fat': '0', 'carbs': '73', 'restaurant': 'A&W Restaurants'}
# {'name': 'Lime Slushee', 'category': 'Drinks', 'calories': '480', 'fat': '0', 'carbs': '119', 'restaurant': 'A&W Restaurants'}
# {'name': 'A&W® Root Beer', 'category': 'Drinks', 'calories': '880', 'fat': '0', 'carbs': '232', 'restaurant': 'A&W Restaurants'}
# {'name': 'Cheeseburger', 'category': 'Burgers', 'calories': '420', 'fat': '21', 'carbs': '37', 'restaurant': 'A&W Restaurants'}
# {'name': 'French Fries (Regular)', 'category': 'French Fries', 'calories': '310', 'fat': '12', 'carbs': '45', 'restaurant': 'A&W Restaurants'}
# {'name': 'Cheese Curds (Large)', 'category': 'Sides', 'calories': '1140', 'fat': '80', 'carbs': '54', 'restaurant': 'A&W Restaurants'}
# {'name': 'Chocolate Milkshake (small)', 'category': 'Shakes', 'calories': '700', 'fat': '29', 'carbs': '100', 'restaurant': 'A&W Restaurants'}
# {'name': 'Orange Freeze (small)', 'category': 'Shakes', 'calories': '450', 'fat': '8', 'carbs': '108', 'restaurant': 'A&W Restaurants'}
# {'name': 'A&W® Diet Root Beer Float (small)', 'category': 'Shakes', 'calories': '170', 'fat': '5', 'carbs': '30', 'restaurant': 'A&W Restaurants'}
# {'name': 'Strawberry Smoothee', 'category': 'Shakes', 'calories': '610', 'fat': '10', 'carbs': '121', 'restaurant': 'A&W Restaurants'}
# {'name': 'Limeade', 'category': 'Drinks', 'calories': '140', 'fat': '0', 'carbs': '38', 'restaurant': 'A&W Restaurants'}
# {'name': 'Cherry Limeade', 'category': 'Drinks', 'calories': '340', 'fat': '0', 'carbs': '90', 'restaurant': 'A&W Restaurants'}
# {'name': 'Lemon Slushee', 'category': 'Drinks', 'calories': '330', 'fat': '0', 'carbs': '82', 'restaurant': 'A&W Restaurants'}
# {'name': 'Blue Raspberry Slushee', 'category': 'Drinks', 'calories': '570', 'fat': '0', 'carbs': '142', 'restaurant': 'A&W Restaurants'}
# {'name': 'A&W® Diet Root Beer', 'category': 'Drinks', 'calories': '0', 'fat': '0', 'carbs': '0', 'restaurant': 'A&W Restaurants'}
# {'name': 'Grilled Chicken Sandwich', 'category': 'Chicken', 'calories': '400', 'fat': '15', 'carbs': '31', 'restaurant': 'A&W Restaurants'}
# {'name': 'French Fries (Large)', 'category': 'French Fries', 'calories': '430', 'fat': '17', 'carbs': '61', 'restaurant': 'A&W Restaurants'}
# {'name': 'Chili', 'category': 'Sides', 'calories': '190', 'fat': '6', 'carbs': '22', 'restaurant': 'A&W Restaurants'}
# {'name': 'Chocolate Milkshake (medium)', 'category': 'Shakes', 'calories': '880', 'fat': '36', 'carbs': '125', 'restaurant': 'A&W Restaurants'}
# {'name': 'Orange Freeze (medium)', 'category': 'Shakes', 'calories': '600', 'fat': '10', 'carbs': '142', 'restaurant': 'A&W Restaurants'}
# {'name': 'A&W® Diet Root Beer Float (medium)', 'category': 'Shakes', 'calories': '170', 'fat': '5', 'carbs': '30', 'restaurant': 'A&W Restaurants'}
# {'name': 'Orange Float (large)', 'category': 'Shakes', 'calories': '610', 'fat': '9', 'carbs': '137', 'restaurant': 'A&W Restaurants'}
# {'name': "Reese's® Peanut Butter Fudge Blendrrr", 'category': 'Desserts', 'calories': '700', 'fat': '41', 'carbs': '103', 'restaurant': 'A&W Restaurants'}
# {'name': 'Limeade', 'category': 'Drinks', 'calories': '210', 'fat': '0', 'carbs': '55', 'restaurant': 'A&W Restaurants'}
# {'name': 'Cherry Limeade', 'category': 'Drinks', 'calories': '530', 'fat': '0', 'carbs': '138', 'restaurant': 'A&W Restaurants'}
# {'name': 'Lemon Slushee', 'category': 'Drinks', 'calories': '440', 'fat': '0', 'carbs': '110', 'restaurant': 'A&W Restaurants'}
# {'name': 'Blue Raspberry Slushee', 'category': 'Drinks', 'calories': '740', 'fat': '0', 'carbs': '182', 'restaurant': 'A&W Restaurants'}
# {'name': 'A&W® Diet Root Beer', 'category': 'Drinks', 'calories': '0', 'fat': '0', 'carbs': '0', 'restaurant': 'A&W Restaurants'}
# {'name': 'Original Double Cheeseburger', 'category': 'Burgers', 'calories': '680', 'fat': '38', 'carbs': '44', 'restaurant': 'A&W Restaurants'}
# {'name': 'Coney (Chili) Cheese Dog', 'category': 'Entrees', 'calories': '380', 'fat': '23', 'carbs': '28', 'restaurant': 'A&W Restaurants'}
# {'name': 'Breaded Onion Rings (Regular)', 'category': 'Sides', 'calories': '350', 'fat': '16', 'carbs': '45', 'restaurant': 'A&W Restaurants'}
# {'name': 'Strawberry Milkshake (medium)', 'category': 'Shakes', 'calories': '840', 'fat': '36', 'carbs': '113', 'restaurant': 'A&W Restaurants'}
# {'name': 'A&W® Diet Root Beer Freeze (small)', 'category': 'Shakes', 'calories': '260', 'fat': '8', 'carbs': '39', 'restaurant': 'A&W Restaurants'}
# {'name': 'A&W® Root Beer Float (small)', 'category': 'Shakes', 'calories': '330', 'fat': '5', 'carbs': '70', 'restaurant': 'A&W Restaurants'}
# {'name': 'Strawberry Banana Smoothee', 'category': 'Shakes', 'calories': '680', 'fat': '10', 'carbs': '137', 'restaurant': 'A&W Restaurants'}
# {'name': 'Oreo® Cookies & Cream Blendrrr', 'category': 'Desserts', 'calories': '340', 'fat': '12', 'carbs': '56', 'restaurant': 'A&W Restaurants'}
# {'name': 'Strawberry Limeade', 'category': 'Drinks', 'calories': '560', 'fat': '0', 'carbs': '143', 'restaurant': 'A&W Restaurants'}
# {'name': 'Watermelon Slushee', 'category': 'Drinks', 'calories': '360', 'fat': '0', 'carbs': '99', 'restaurant': 'A&W Restaurants'}
# {'name': 'Lime Slushee', 'category': 'Drinks', 'calories': '770', 'fat': '0', 'carbs': '188', 'restaurant': 'A&W Restaurants'}
# {'name': 'A&W® Root Beer', 'category': 'Drinks', 'calories': '1760', 'fat': '0', 'carbs': '464', 'restaurant': 'A&W Restaurants'}
# {'name': 'Papa Single Burger', 'category': 'Burgers', 'calories': '470', 'fat': '25', 'carbs': '38', 'restaurant': 'A&W Restaurants'}
# {'name': 'Hot Dog (plain)', 'category': 'Entrees', 'calories': '310', 'fat': '19', 'carbs': '23', 'restaurant': 'A&W Restaurants'}
# {'name': 'Cheese Fries', 'category': 'French Fries', 'calories': '390', 'fat': '18', 'carbs': '50', 'restaurant': 'A&W Restaurants'}
# {'name': "Reese's® Polar Swirl®", 'category': 'Desserts', 'calories': '740', 'fat': '31', 'carbs': '97', 'restaurant': 'A&W Restaurants'}
# {'name': 'A&W® Root Beer Freeze (medium)', 'category': 'Shakes', 'calories': '480', 'fat': '10', 'carbs': '89', 'restaurant': 'A&W Restaurants'}
# {'name': 'Hot Fudge Sundae', 'category': 'Desserts', 'calories': '350', 'fat': '11', 'carbs': '54', 'restaurant': 'A&W Restaurants'}
# {'name': 'Strawberry Banana Smoothee', 'category': 'Shakes', 'calories': '390', 'fat': '6', 'carbs': '78', 'restaurant': 'A&W Restaurants'}
# {'name': 'Chocolate Fudge Blendrrr', 'category': 'Desserts', 'calories': '560', 'fat': '32', 'carbs': '92', 'restaurant': 'A&W Restaurants'}
# {'name': 'Strawberry Limeade', 'category': 'Drinks', 'calories': '290', 'fat': '0', 'carbs': '75', 'restaurant': 'A&W Restaurants'}
# {'name': 'Cherry Slushee', 'category': 'Drinks', 'calories': '900', 'fat': '0', 'carbs': '224', 'restaurant': 'A&W Restaurants'}
# {'name': 'Lime Slushee', 'category': 'Drinks', 'calories': '380', 'fat': '0', 'carbs': '94', 'restaurant': 'A&W Restaurants'}
# {'name': 'A&W® Root Beer', 'category': 'Drinks', 'calories': '440', 'fat': '0', 'carbs': '116', 'restaurant': 'A&W Restaurants'}
# {'name': 'Original Bacon Cheeseburger', 'category': 'Burgers', 'calories': '530', 'fat': '30', 'carbs': '39', 'restaurant': 'A&W Restaurants'}
# {'name': 'Cheese Dog', 'category': 'Entrees', 'calories': '350', 'fat': '22', 'carbs': '26', 'restaurant': 'A&W Restaurants'}
# {'name': 'Breaded Onion Rings (Large)', 'category': 'Sides', 'calories': '480', 'fat': '27', 'carbs': '62', 'restaurant': 'A&W Restaurants'}
# {'name': 'Vanilla Milkshake (small)', 'category': 'Shakes', 'calories': '720', 'fat': '31', 'carbs': '97', 'restaurant': 'A&W Restaurants'}
# {'name': 'A&W® Diet Root Beer Freeze (medium)', 'category': 'Shakes', 'calories': '340', 'fat': '10', 'carbs': '53', 'restaurant': 'A&W Restaurants'}
# {'name': 'A&W® Root Beer Float (medium)', 'category': 'Shakes', 'calories': '350', 'fat': '5', 'carbs': '77', 'restaurant': 'A&W Restaurants'}
# {'name': 'Strawberry Smoothee', 'category': 'Shakes', 'calories': '360', 'fat': '6', 'carbs': '70', 'restaurant': 'A&W Restaurants'}
# {'name': 'Oreo® Cookies & Cream Blendrrr', 'category': 'Desserts', 'calories': '430', 'fat': '15', 'carbs': '72', 'restaurant': 'A&W Restaurants'}
# {'name': 'Cherry Limeade', 'category': 'Drinks', 'calories': '190', 'fat': '0', 'carbs': '51', 'restaurant': 'A&W Restaurants'}
# {'name': 'Watermelon Slushee', 'category': 'Drinks', 'calories': '460', 'fat': '0', 'carbs': '124', 'restaurant': 'A&W Restaurants'}
# {'name': 'Blue Raspberry Slushee', 'category': 'Drinks', 'calories': '270', 'fat': '0', 'carbs': '67', 'restaurant': 'A&W Restaurants'}
# {'name': 'A&W® Diet Root Beer', 'category': 'Drinks', 'calories': '0', 'fat': '0', 'carbs': '0', 'restaurant': 'A&W Restaurants'}
# {'name': 'Hamburger', 'category': 'Burgers', 'calories': '380', 'fat': '19', 'carbs': '33', 'restaurant': 'A&W Restaurants'}
# {'name': 'French Fries (Small/ Kids)', 'category': 'French Fries', 'calories': '200', 'fat': '8', 'carbs': '28', 'restaurant': 'A&W Restaurants'}
# {'name': 'Cheese Curds (Regular)', 'category': 'Sides', 'calories': '570', 'fat': '40', 'carbs': '27', 'restaurant': 'A&W Restaurants'}
# {'name': 'Vanilla Milkshake (medium', 'category': 'Shakes', 'calories': '900', 'fat': '39', 'carbs': '121', 'restaurant': 'A&W Restaurants'}
# {'name': 'A&W® Diet Root Beer Freeze (large)', 'category': 'Shakes', 'calories': '600', 'fat': '18', 'carbs': '92', 'restaurant': 'A&W Restaurants'}
# {'name': 'A&W® Root Beer Float (large)', 'category': 'Shakes', 'calories': '640', 'fat': '10', 'carbs': '136', 'restaurant': 'A&W Restaurants'}
# {'name': 'Strawberry Smoothee', 'category': 'Shakes', 'calories': '370', 'fat': '6', 'carbs': '74', 'restaurant': 'A&W Restaurants'}
# {'name': 'Oreo® Cookies & Cream Blendrrr', 'category': 'Desserts', 'calories': '650', 'fat': '21', 'carbs': '109', 'restaurant': 'A&W Restaurants'}
# {'name': 'Cherry Limeade', 'category': 'Drinks', 'calories': '300', 'fat': '0', 'carbs': '79', 'restaurant': 'A&W Restaurants'}
# {'name': 'Watermelon Slushee', 'category': 'Drinks', 'calories': '720', 'fat': '0', 'carbs': '197', 'restaurant': 'A&W Restaurants'}
# {'name': 'Blue Raspberry Slushee', 'category': 'Drinks', 'calories': '370', 'fat': '0', 'carbs': '91', 'restaurant': 'A&W Restaurants'}
# {'name': 'A&W® Diet Root Beer', 'category': 'Drinks', 'calories': '0', 'fat': '0', 'carbs': '0', 'restaurant': 'A&W Restaurants'}
# {'name': 'Chicken Strips- 3 pieces', 'category': 'Chicken', 'calories': '500', 'fat': '29', 'carbs': '32', 'restaurant': 'A&W Restaurants'}
# {'name': 'Corn Dog Nuggets® (Regular)', 'category': 'Sides', 'calories': '280', 'fat': '13', 'carbs': '32', 'restaurant': 'A&W Restaurants'}
# {'name': "M&M's® Polar Swirl®", 'category': 'Desserts', 'calories': '710', 'fat': '25', 'carbs': '107', 'restaurant': 'A&W Restaurants'}
# {'name': 'Vanilla Cone (large)', 'category': 'Desserts', 'calories': '260', 'fat': '7', 'carbs': '41', 'restaurant': 'A&W Restaurants'}
# {'name': 'Strawberry Sundae', 'category': 'Desserts', 'calories': '300', 'fat': '8', 'carbs': '47', 'restaurant': 'A&W Restaurants'}
# {'name': 'Pineapple Banana Smoothee', 'category': 'Shakes', 'calories': '480', 'fat': '6', 'carbs': '104', 'restaurant': 'A&W Restaurants'}
# {'name': "Reese's® Peanut Butter Fudge Blendrrr", 'category': 'Desserts', 'calories': '1360', 'fat': '79', 'carbs': '203', 'restaurant': 'A&W Restaurants'}
# {'name': 'Limeade', 'category': 'Drinks', 'calories': '390', 'fat': '0', 'carbs': '103', 'restaurant': 'A&W Restaurants'}
# {'name': 'Cherry Slushee', 'category': 'Drinks', 'calories': '450', 'fat': '0', 'carbs': '112', 'restaurant': 'A&W Restaurants'}
# {'name': 'Lemon Slushee', 'category': 'Drinks', 'calories': '890', 'fat': '0', 'carbs': '221', 'restaurant': 'A&W Restaurants'}
# {'name': 'A&W® Root Beer', 'category': 'Drinks', 'calories': '220', 'fat': '0', 'carbs': '58', 'restaurant': 'A&W Restaurants'}
# {'name': 'A&W® Diet Root Beer', 'category': 'Drinks', 'calories': '0', 'fat': '0', 'carbs': '0', 'restaurant': 'A&W Restaurants'}
# {'name': 'Crispy Chicken Sandwich', 'category': 'Chicken', 'calories': '550', 'fat': '25', 'carbs': '52', 'restaurant': 'A&W Restaurants'}
# {'name': 'Corn Dog Nuggets® (Small/ Kids)', 'category': 'Sides', 'calories': '180', 'fat': '8', 'carbs': '20', 'restaurant': 'A&W Restaurants'}
# {'name': 'Extra Burger Patty', 'category': 'Sides', 'calories': '170', 'fat': '12', 'carbs': '2', 'restaurant': 'A&W Restaurants'}
# {'name': 'Vanilla Cone (regular)', 'category': 'Desserts', 'calories': '200', 'fat': '5', 'carbs': '32', 'restaurant': 'A&W Restaurants'}
# {'name': 'Orange Freeze (medium)', 'category': 'Shakes', 'calories': '970', 'fat': '18', 'carbs': '223', 'restaurant': 'A&W Restaurants'}
# {'name': 'A&W® Diet Root Beer Float (large)', 'category': 'Shakes', 'calories': '350', 'fat': '10', 'carbs': '60', 'restaurant': 'A&W Restaurants'}
# {'name': 'Pineapple Banana Smoothee', 'category': 'Shakes', 'calories': '400', 'fat': '6', 'carbs': '85', 'restaurant': 'A&W Restaurants'}
# {'name': "Reese's® Peanut Butter Fudge Blendrrr", 'category': 'Desserts', 'calories': '710', 'fat': '41', 'carbs': '108', 'restaurant': 'A&W Restaurants'}
# {'name': 'Limeade', 'category': 'Drinks', 'calories': '250', 'fat': '0', 'carbs': '66', 'restaurant': 'A&W Restaurants'}
# {'name': 'Cherry Slushee', 'category': 'Drinks', 'calories': '330', 'fat': '0', 'carbs': '83', 'restaurant': 'A&W Restaurants'}
# {'name': 'Lemon Slushee', 'category': 'Drinks', 'calories': '560', 'fat': '0', 'carbs': '139', 'restaurant': 'A&W Restaurants'}
# {'name': 'A&W® Root Beer', 'category': 'Drinks', 'calories': '160', 'fat': '0', 'carbs': '43', 'restaurant': 'A&W Restaurants'}
# {'name': 'A&W® Diet Root Beer', 'category': 'Drinks', 'calories': '0', 'fat': '0', 'carbs': '0', 'restaurant': 'A&W Restaurants'}
# {'name': 'Papa Burger®', 'category': 'Burgers', 'calories': '690', 'fat': '39', 'carbs': '44', 'restaurant': 'A&W Restaurants'}
# {'name': 'Crunchy Shrimp', 'category': 'Seafood', 'calories': '340', 'fat': '19', 'carbs': '34', 'restaurant': 'A&W Restaurants'}
# {'name': 'Chili Cheese Fries', 'category': 'French Fries', 'calories': '410', 'fat': '17', 'carbs': '52', 'restaurant': 'A&W Restaurants'}
# {'name': 'Oreo® Polar Swirl®', 'category': 'Desserts', 'calories': '690', 'fat': '24', 'carbs': '107', 'restaurant': 'A&W Restaurants'}
# {'name': 'A&W® Root Beer Freeze (small)', 'category': 'Shakes', 'calories': '370', 'fat': '8', 'carbs': '68', 'restaurant': 'A&W Restaurants'}
# {'name': 'Chocolate Sundae', 'category': 'Desserts', 'calories': '320', 'fat': '8', 'carbs': '53', 'restaurant': 'A&W Restaurants'}
# {'name': 'Pineapple Banana Smoothee', 'category': 'Shakes', 'calories': '750', 'fat': '10', 'carbs': '160', 'restaurant': 'A&W Restaurants'}
# {'name': 'Chocolate Fudge Blendrrr', 'category': 'Desserts', 'calories': '490', 'fat': '30', 'carbs': '68', 'restaurant': 'A&W Restaurants'}
# {'name': 'Strawberry Limeade', 'category': 'Drinks', 'calories': '230', 'fat': '0', 'carbs': '58', 'restaurant': 'A&W Restaurants'}
# {'name': 'Cherry Slushee', 'category': 'Drinks', 'calories': '570', 'fat': '0', 'carbs': '141', 'restaurant': 'A&W Restaurants'}
# {'name': 'Lime Slushee', 'category': 'Drinks', 'calories': '280', 'fat': '0', 'carbs': '69', 'restaurant': 'A&W Restaurants'}
# {'name': 'A&W® Root Beer', 'category': 'Drinks', 'calories': '270', 'fat': '0', 'carbs': '72', 'restaurant': 'A&W Restaurants'}
# {'name': 'Applebee’s House Salad (without dressing)', 'category': 'Salads', 'calories': '180', 'fat': '15', 'carbs': '12', 'restaurant': "Applebee's"}
# {'name': 'Baked Potato', 'category': 'Sides', 'calories': '430', 'fat': '28', 'carbs': '42', 'restaurant': "Applebee's"}
# {'name': 'Boneless Wings, Southern BBQ', 'category': 'Appetizers', 'calories': '1110', 'fat': '55', 'carbs': '83', 'restaurant': "Applebee's"}
# {'name': 'Bruschetta Chicken Salad, Half w/o dressing', 'category': 'Salads', 'calories': '580', 'fat': '30', 'carbs': '40', 'restaurant': "Applebee's"}
# {'name': 'Cheese Quesadilla Grande', 'category': 'Appetizers', 'calories': '1130', 'fat': '87', 'carbs': '85', 'restaurant': "Applebee's"}
# {'name': 'Chicken Fettuccine Carbonara', 'category': 'Entrees', 'calories': '1440', 'fat': '82', 'carbs': '107', 'restaurant': "Applebee's"}
# {'name': 'Chicken Tortilla Soup', 'category': 'Soups', 'calories': '140', 'fat': '7', 'carbs': '12', 'restaurant': "Applebee's"}
# {'name': 'Classic Club House Grill', 'category': 'Sandwiches', 'calories': '1150', 'fat': '67', 'carbs': '77', 'restaurant': "Applebee's"}
# {'name': 'Crunchy Onion Rings, Side', 'category': 'Sides', 'calories': '530', 'fat': '28', 'carbs': '63', 'restaurant': "Applebee's"}
# {'name': 'French Onion Soup', 'category': 'Soups', 'calories': '260', 'fat': '14', 'carbs': '16', 'restaurant': "Applebee's"}
# {'name': 'Frozen Lemonades', 'category': 'Drinks', 'calories': '255', 'fat': '0', 'carbs': '64', 'restaurant': "Applebee's"}
# {'name': 'Grilled Shrimp ‘N Spinach Salad', 'category': 'Salads', 'calories': '260', 'fat': '15', 'carbs': '20', 'restaurant': "Applebee's"}
# {'name': 'Grilled Steak Caesar, Half w/o dressing', 'category': 'Salads', 'calories': '230', 'fat': '10', 'carbs': '11', 'restaurant': "Applebee's"}
# {'name': 'House Sirloin', 'category': 'Entrees', 'calories': '250', 'fat': '12', 'carbs': '0', 'restaurant': "Applebee's"}
# {'name': 'Kids Grape Juice (6.75 oz)', 'category': "Kid's Meals", 'calories': '80', 'fat': '0', 'carbs': '20', 'restaurant': "Applebee's"}
# {'name': 'Kids Mini Hamburger – 1', 'category': "Kid's Meals", 'calories': '390', 'fat': '27', 'carbs': '23', 'restaurant': "Applebee's"}
# {'name': 'Kids Vanilla Sundae with Hershey’s Syrup', 'category': "Kid's Meals", 'calories': '330', 'fat': '14', 'carbs': '49', 'restaurant': "Applebee's"}
# {'name': 'Oriental Chicken Salad', 'category': 'Salads', 'calories': '420', 'fat': '29', 'carbs': '25', 'restaurant': "Applebee's"}
# {'name': 'Pecan-Crusted Chicken Salad, Half', 'category': 'Salads', 'calories': '820', 'fat': '48', 'carbs': '72', 'restaurant': "Applebee's"}
# {'name': 'Queso Blanco', 'category': 'Appetizers', 'calories': '1330', 'fat': '82', 'carbs': '114', 'restaurant': "Applebee's"}
# {'name': 'Santa Fe Chicken Salad, Regular w/o dressing', 'category': 'Salads', 'calories': '870', 'fat': '56', 'carbs': '52', 'restaurant': "Applebee's"}
# {'name': 'Sizzling Skillet Fajitas - Combo', 'category': 'Entrees', 'calories': '1430', 'fat': '60', 'carbs': '150', 'restaurant': "Applebee's"}
# {'name': 'Spinach & Artichoke Dip', 'category': 'Appetizers', 'calories': '1525', 'fat': '102', 'carbs': '124', 'restaurant': "Applebee's"}
# {'name': 'Teriyaki Chicken Pasta', 'category': 'Entrees', 'calories': '450', 'fat': '8', 'carbs': '73', 'restaurant': "Applebee's"}
# {'name': 'Trios Chicken Quesadilla Grande', 'category': 'Appetizers', 'calories': '650', 'fat': '47', 'carbs': '44', 'restaurant': "Applebee's"}
# {'name': 'Trios Spinach Artichoke Dip', 'category': 'Appetizers', 'calories': '560', 'fat': '39', 'carbs': '41', 'restaurant': "Applebee's"}
# {'name': 'Weight Watchers® Spicy Pineapple Glazed Shrimp & Spinach', 'category': 'Seafood', 'calories': '310', 'fat': '5', 'carbs': '48', 'restaurant': "Applebee's"}
# {'name': 'Applebee’s House Salad', 'category': 'Salads', 'calories': '180', 'fat': '15', 'carbs': '12', 'restaurant': "Applebee's"}
# {'name': 'Bacon Cheese Chicken Grill', 'category': 'Sandwiches', 'calories': '750', 'fat': '33', 'carbs': '50', 'restaurant': "Applebee's"}
# {'name': 'Boneless Wings, Hot Buffalo', 'category': 'Appetizers', 'calories': '1170', 'fat': '69', 'carbs': '67', 'restaurant': "Applebee's"}
# {'name': 'Bruschetta Chicken Salad, Half', 'category': 'Salads', 'calories': '740', 'fat': '44', 'carbs': '45', 'restaurant': "Applebee's"}
# {'name': 'California Turkey Club', 'category': 'Sandwiches', 'calories': '970', 'fat': '55', 'carbs': '60', 'restaurant': "Applebee's"}
# {'name': 'Chicken Fajita Rollup', 'category': 'Sandwiches', 'calories': '560', 'fat': '41', 'carbs': '45', 'restaurant': "Applebee's"}
# {'name': 'Chicken Tortilla Soup', 'category': 'Soups', 'calories': '180', 'fat': '8', 'carbs': '18', 'restaurant': "Applebee's"}
# {'name': 'Clam Chowder', 'category': 'Soups', 'calories': '290', 'fat': '20', 'carbs': '16', 'restaurant': "Applebee's"}
# {'name': 'Crunchy Onion Rings', 'category': 'Appetizers', 'calories': '1290', 'fat': '56', 'carbs': '181', 'restaurant': "Applebee's"}
# {'name': 'French Dip Sliders', 'category': 'Burgers', 'calories': '590', 'fat': '36', 'carbs': '50', 'restaurant': "Applebee's"}
# {'name': 'Fries, Side', 'category': "Kid's Meals", 'calories': '390', 'fat': '18', 'carbs': '53', 'restaurant': "Applebee's"}
# {'name': 'Grilled Dijon Chicken & Portobellos', 'category': 'Chicken', 'calories': '470', 'fat': '16', 'carbs': '30', 'restaurant': "Applebee's"}
# {'name': 'Grilled Steak Caesar, Half', 'category': 'Salads', 'calories': '460', 'fat': '34', 'carbs': '13', 'restaurant': "Applebee's"}
# {'name': 'House Sirloin', 'category': 'Entrees', 'calories': '310', 'fat': '13', 'carbs': '0', 'restaurant': "Applebee's"}
# {'name': 'Kids Fried Shrimp', 'category': "Kid's Meals", 'calories': '230', 'fat': '14', 'carbs': '16', 'restaurant': "Applebee's"}
# {'name': 'Kids Mini Cheeseburgers – 2', 'category': "Kid's Meals", 'calories': '740', 'fat': '46', 'carbs': '47', 'restaurant': "Applebee's"}
# {'name': 'Kids Vanilla Sundae', 'category': "Kid's Meals", 'calories': '230', 'fat': '14', 'carbs': '24', 'restaurant': "Applebee's"}
# {'name': 'Oriental Chicken Rollup', 'category': 'Sandwiches', 'calories': '1160', 'fat': '60', 'carbs': '121', 'restaurant': "Applebee's"}
# {'name': 'Oriental Grilled Chicken Salad, Regular w/o dressing', 'category': 'Salads', 'calories': '590', 'fat': '19', 'carbs': '58', 'restaurant': "Applebee's"}
# {'name': 'Quesadilla Burger', 'category': 'Burgers', 'calories': '1240', 'fat': '103', 'carbs': '44', 'restaurant': "Applebee's"}
# {'name': 'Santa Fe Chicken Salad, Regular', 'category': 'Salads', 'calories': '1240', 'fat': '93', 'carbs': '58', 'restaurant': "Applebee's"}
# {'name': 'Sizzling Skillet Fajitas - Chicken', 'category': 'Entrees', 'calories': '1370', 'fat': '52', 'carbs': '149', 'restaurant': "Applebee's"}
# {'name': 'Spicy Chili Cheese Nachos', 'category': 'Appetizers', 'calories': '1610', 'fat': '103', 'carbs': '125', 'restaurant': "Applebee's"}
# {'name': 'Stuffed Meatball Sandwich', 'category': 'Sandwiches', 'calories': '1090', 'fat': '58', 'carbs': '90', 'restaurant': "Applebee's"}
# {'name': 'Trios Cheeseburger Sliders', 'category': 'Appetizers', 'calories': '880', 'fat': '59', 'carbs': '55', 'restaurant': "Applebee's"}
# {'name': 'Trios Spicy Queso Blanco', 'category': 'Appetizers', 'calories': '520', 'fat': '33', 'carbs': '40', 'restaurant': "Applebee's"}
# {'name': 'Weight Watchers® Paradise Chicken Salad', 'category': 'Salads', 'calories': '340', 'fat': '4', 'carbs': '6', 'restaurant': "Applebee's"}
# {'name': 'Appetizer Sampler', 'category': 'Appetizers', 'calories': '2375', 'fat': '162', 'carbs': '169', 'restaurant': "Applebee's"}
# {'name': 'Applebee’s Riblets Basket', 'category': 'Ribs', 'calories': '1115', 'fat': '55', 'carbs': '92', 'restaurant': "Applebee's"}
# {'name': 'Black Bean Soup', 'category': 'Soups', 'calories': '190', 'fat': '9', 'carbs': '21', 'restaurant': "Applebee's"}
# {'name': 'Breadstick', 'category': 'Sides', 'calories': '290', 'fat': '19', 'carbs': '22', 'restaurant': "Applebee's"}
# {'name': 'Cajun Shrimp Pasta', 'category': 'Entrees', 'calories': '1170', 'fat': '69', 'carbs': '95', 'restaurant': "Applebee's"}
# {'name': 'Cheeseburger Sliders with Applewood Smoked Bacon', 'category': 'Burgers', 'calories': '1330', 'fat': '87', 'carbs': '83', 'restaurant': "Applebee's"}
# {'name': 'Chicken Noodle Soup', 'category': 'Soups', 'calories': '110', 'fat': '3', 'carbs': '11', 'restaurant': "Applebee's"}
# {'name': 'Chili Cheese Nachos', 'category': 'Appetizers', 'calories': '1680', 'fat': '107', 'carbs': '134', 'restaurant': "Applebee's"}
# {'name': 'Classic Wings, Southern BBQ', 'category': 'Appetizers', 'calories': '660', 'fat': '35', 'carbs': '25', 'restaurant': "Applebee's"}
# {'name': 'Double-Glazed Baby Back Ribs - Half Rack', 'category': 'Ribs', 'calories': '935', 'fat': '49', 'carbs': '88', 'restaurant': "Applebee's"}
# {'name': 'Fried Chicken Salad, Half w/o dressing', 'category': 'Salads', 'calories': '310', 'fat': '23', 'carbs': '12', 'restaurant': "Applebee's"}
# {'name': 'Grilled Chicken Caesar, Half w/o dressing', 'category': 'Salads', 'calories': '180', 'fat': '5', 'carbs': '10', 'restaurant': "Applebee's"}
# {'name': 'Grilled Shrimp ‘N Spinach Salad, Regular w/o dressing', 'category': 'Salads', 'calories': '680', 'fat': '51', 'carbs': '20', 'restaurant': "Applebee's"}
# {'name': 'Hand-Battered Fish & Chips', 'category': 'Seafood', 'calories': '1570', 'fat': '106', 'carbs': '108', 'restaurant': "Applebee's"}
# {'name': 'Kids Celery side with Dressing', 'category': "Kid's Meals", 'calories': '220', 'fat': '22', 'carbs': '5', 'restaurant': "Applebee's"}
# {'name': 'Kids Hot Dog', 'category': "Kid's Meals", 'calories': '330', 'fat': '18', 'carbs': '31', 'restaurant': "Applebee's"}
# {'name': 'Kids OREO® Cookie Sundae', 'category': "Kid's Meals", 'calories': '360', 'fat': '19', 'carbs': '43', 'restaurant': "Applebee's"}
# {'name': 'Margherita Chicken', 'category': 'Chicken', 'calories': '800', 'fat': '30', 'carbs': '67', 'restaurant': "Applebee's"}
# {'name': 'Oriental Chicken Salad, Regular w/o dressing', 'category': 'Salads', 'calories': '680', 'fat': '41', 'carbs': '50', 'restaurant': "Applebee's"}
# {'name': 'Philly Burger', 'category': 'Burgers', 'calories': '1130', 'fat': '67', 'carbs': '70', 'restaurant': "Applebee's"}
# {'name': 'Riblet and Chicken Tenders Basket', 'category': 'Chicken', 'calories': '1295', 'fat': '73', 'carbs': '103', 'restaurant': "Applebee's"}
# {'name': 'Signature Sirloin with Garlic Herb Shrimp', 'category': 'Entrees', 'calories': '500', 'fat': '21', 'carbs': '31', 'restaurant': "Applebee's"}
# {'name': 'Sizzling Steak & Cheese', 'category': 'Entrees', 'calories': '1050', 'fat': '65', 'carbs': '49', 'restaurant': "Applebee's"}
# {'name': 'Steak & Honey BBQ Chicken Combo', 'category': 'Entrees', 'calories': '600', 'fat': '15', 'carbs': '37', 'restaurant': "Applebee's"}
# {'name': 'Toasted Garlic Bread Basket', 'category': 'Sides', 'calories': '1120', 'fat': '78', 'carbs': '89', 'restaurant': "Applebee's"}
# {'name': 'Trios Boneless Wings, Honey BBQ', 'category': 'Appetizers', 'calories': '620', 'fat': '28', 'carbs': '58', 'restaurant': "Applebee's"}
# {'name': 'Trios Classic Wings, Southern BBQ', 'category': 'Appetizers', 'calories': '330', 'fat': '17', 'carbs': '13', 'restaurant': "Applebee's"}
# {'name': 'Triple Chocolate Meltdown®', 'category': 'Desserts', 'calories': '820', 'fat': '48', 'carbs': '97', 'restaurant': "Applebee's"}
# {'name': 'Wonton Tacos', 'category': 'Appetizers', 'calories': '495', 'fat': '23', 'carbs': '45', 'restaurant': "Applebee's"}
# {'name': 'Apple Walnut Chicken Salad, Half', 'category': 'Salads', 'calories': '630', 'fat': '43', 'carbs': '33', 'restaurant': "Applebee's"}
# {'name': 'Applebee’s Riblets Platter', 'category': 'Ribs', 'calories': '1705', 'fat': '86', 'carbs': '134', 'restaurant': "Applebee's"}
# {'name': 'Blackened Tilapia Sandwich', 'category': 'Sandwiches', 'calories': '740', 'fat': '42', 'carbs': '54', 'restaurant': "Applebee's"}
# {'name': 'Broccoli Cheddar Soup', 'category': 'Soups', 'calories': '340', 'fat': '26', 'carbs': '19', 'restaurant': "Applebee's"}
# {'name': 'California Shrimp Salad, Half', 'category': 'Salads', 'calories': '500', 'fat': '42', 'carbs': '16', 'restaurant': "Applebee's"}
# {'name': 'Cheesy Corn', 'category': 'Sides', 'calories': '350', 'fat': '20', 'carbs': '28', 'restaurant': "Applebee's"}
# {'name': 'Chicken Parmesan Stack', 'category': 'Chicken', 'calories': '1690', 'fat': '95', 'carbs': '130', 'restaurant': "Applebee's"}
# {'name': 'Chips and Spicy Chipotle Lime Salsa', 'category': 'Appetizers', 'calories': '960', 'fat': '53', 'carbs': '106', 'restaurant': "Applebee's"}
# {'name': 'Classic Wings, Sweet & spicy sauce', 'category': 'Appetizers', 'calories': '690', 'fat': '35', 'carbs': '32', 'restaurant': "Applebee's"}
# {'name': 'Fiesta Lime Chicken®', 'category': 'Chicken', 'calories': '1160', 'fat': '67', 'carbs': '94', 'restaurant': "Applebee's"}
# {'name': 'Fried Chicken Salad, Regular', 'category': 'Salads', 'calories': '980', 'fat': '79', 'carbs': '50', 'restaurant': "Applebee's"}
# {'name': 'Grilled Chicken Caesar, Regular', 'category': 'Salads', 'calories': '820', 'fat': '57', 'carbs': '25', 'restaurant': "Applebee's"}
# {'name': 'Hand-Battered Fish Sandwich', 'category': 'Sandwiches', 'calories': '860', 'fat': '58', 'carbs': '63', 'restaurant': "Applebee's"}
# {'name': 'Kids Cheese Pizza', 'category': "Kid's Meals", 'calories': '550', 'fat': '31', 'carbs': '44', 'restaurant': "Applebee's"}
# {'name': 'Kids Hot Fudge Sundae', 'category': "Kid's Meals", 'calories': '350', 'fat': '18', 'carbs': '45', 'restaurant': "Applebee's"}
# {'name': 'Kids Pasta with Marinara Sauce', 'category': "Kid's Meals", 'calories': '360', 'fat': '7', 'carbs': '60', 'restaurant': "Applebee's"}
# {'name': 'Mozzarella Sticks', 'category': 'Appetizers', 'calories': '940', 'fat': '48', 'carbs': '84', 'restaurant': "Applebee's"}
# {'name': 'Oriental Grilled Chicken Salad', 'category': 'Salads', 'calories': '430', 'fat': '21', 'carbs': '36', 'restaurant': "Applebee's"}
# {'name': 'Pork Wonton Tacos', 'category': 'Appetizers', 'calories': '820', 'fat': '41', 'carbs': '68', 'restaurant': "Applebee's"}
# {'name': 'Riblet and Chicken Tenders Platter', 'category': 'Chicken', 'calories': '1800', 'fat': '101', 'carbs': '136', 'restaurant': "Applebee's"}
# {'name': 'Sizzling Apple Pie', 'category': 'Desserts', 'calories': '900', 'fat': '33', 'carbs': '145', 'restaurant': "Applebee's"}
# {'name': 'Slow Simmered Tender Beef Sandwich', 'category': 'Sandwiches', 'calories': '980', 'fat': '50', 'carbs': '101', 'restaurant': "Applebee's"}
# {'name': 'Steak & Riblets Combo', 'category': 'Entrees', 'calories': '985', 'fat': '49', 'carbs': '39', 'restaurant': "Applebee's"}
# {'name': 'Tomato Basil Soup', 'category': 'Soups', 'calories': '220', 'fat': '13', 'carbs': '22', 'restaurant': "Applebee's"}
# {'name': 'Trios Boneless Wings, Hot Buffalo', 'category': 'Appetizers', 'calories': '590', 'fat': '35', 'carbs': '33', 'restaurant': "Applebee's"}
# {'name': 'Trios Classic Wings, Sweet & spicy sauce', 'category': 'Appetizers', 'calories': '350', 'fat': '18', 'carbs': '16', 'restaurant': "Applebee's"}
# {'name': 'Veggie Burger', 'category': 'Burgers', 'calories': '550', 'fat': '22', 'carbs': '60', 'restaurant': "Applebee's"}
# {'name': 'Zesty Ranch Chicken Sandwich', 'category': 'Sandwiches', 'calories': '1150', 'fat': '73', 'carbs': '76', 'restaurant': "Applebee's"}
# {'name': 'Applebee’s Limeades', 'category': 'Drinks', 'calories': '130', 'fat': '0', 'carbs': '59', 'restaurant': "Applebee's"}
# {'name': 'Baked Potato Soup', 'category': 'Soups', 'calories': '420', 'fat': '32', 'carbs': '27', 'restaurant': "Applebee's"}
# {'name': 'Boneless Wings, Sweet & spicy sauce', 'category': 'Appetizers', 'calories': '1150', 'fat': '55', 'carbs': '90', 'restaurant': "Applebee's"}
# {'name': 'Bruschetta Chicken Salad, Regular', 'category': 'Salads', 'calories': '1110', 'fat': '66', 'carbs': '67', 'restaurant': "Applebee's"}
# {'name': 'Cheeseburger', 'category': 'Burgers', 'calories': '940', 'fat': '58', 'carbs': '52', 'restaurant': "Applebee's"}
# {'name': 'Chicken Fried Chicken', 'category': 'Chicken', 'calories': '1230', 'fat': '59', 'carbs': '112', 'restaurant': "Applebee's"}
# {'name': 'Chili', 'category': 'Soups', 'calories': '310', 'fat': '26', 'carbs': '10', 'restaurant': "Applebee's"}
# {'name': 'Classic Wings, Classic Buffalo', 'category': 'Appetizers', 'calories': '710', 'fat': '49', 'carbs': '8', 'restaurant': "Applebee's"}
# {'name': 'Decadent Shakes', 'category': 'Shakes', 'calories': '915', 'fat': '46', 'carbs': '109', 'restaurant': "Applebee's"}
# {'name': 'Fresh Fruit, Side', 'category': 'Sides', 'calories': '90', 'fat': '0', 'carbs': '24', 'restaurant': "Applebee's"}
# {'name': 'Garlic Herb Salmon', 'category': 'Seafood', 'calories': '690', 'fat': '29', 'carbs': '61', 'restaurant': "Applebee's"}
# {'name': 'Grilled Shrimp ‘N Spinach Salad, Half', 'category': 'Salads', 'calories': '620', 'fat': '44', 'carbs': '33', 'restaurant': "Applebee's"}
# {'name': 'Grilled Steak Caesar, Regular', 'category': 'Salads', 'calories': '910', 'fat': '68', 'carbs': '25', 'restaurant': "Applebee's"}
# {'name': 'Kids 4oz Sirloin Steak', 'category': "Kid's Meals", 'calories': '140', 'fat': '7', 'carbs': '0', 'restaurant': "Applebee's"}
# {'name': 'Kids Grilled Cheese (Hawaiian bread)', 'category': "Kid's Meals", 'calories': '610', 'fat': '36', 'carbs': '51', 'restaurant': "Applebee's"}
# {'name': 'Kids Mini Hamburger – 2', 'category': "Kid's Meals", 'calories': '660', 'fat': '40', 'carbs': '46', 'restaurant': "Applebee's"}
# {'name': 'Loaded Baked Potato', 'category': 'Sides', 'calories': '500', 'fat': '35', 'carbs': '42', 'restaurant': "Applebee's"}
# {'name': 'Oriental Chicken Salad, Half', 'category': 'Salads', 'calories': '670', 'fat': '49', 'carbs': '42', 'restaurant': "Applebee's"}
# {'name': 'Pecan-Crusted Chicken Salad, Half w/o dressing', 'category': 'Salads', 'calories': '580', 'fat': '31', 'carbs': '53', 'restaurant': "Applebee's"}
# {'name': 'Queso Blanco with chili', 'category': 'Appetizers', 'calories': '1440', 'fat': '89', 'carbs': '118', 'restaurant': "Applebee's"}
# {'name': 'Seasonal Vegetables, Side', 'category': 'Sides', 'calories': '42', 'fat': '0', 'carbs': '8', 'restaurant': "Applebee's"}
# {'name': 'Sizzling Skillet Fajitas - Shrimp', 'category': 'Entrees', 'calories': '1400', 'fat': '65', 'carbs': '151', 'restaurant': "Applebee's"}
# {'name': 'Spinach Salad', 'category': 'Salads', 'calories': '230', 'fat': '15', 'carbs': '19', 'restaurant': "Applebee's"}
# {'name': 'Teriyaki Shrimp Pasta', 'category': 'Entrees', 'calories': '440', 'fat': '8', 'carbs': '74', 'restaurant': "Applebee's"}
# {'name': 'Topper - Sautéed Garlic Mushrooms', 'category': 'Sides', 'calories': '130', 'fat': '12', 'carbs': '4', 'restaurant': "Applebee's"}
# {'name': 'Trios Classic Wings, Classic Buffalo', 'category': 'Appetizers', 'calories': '360', 'fat': '24', 'carbs': '4', 'restaurant': "Applebee's"}
# {'name': 'Trios Steak Quesadilla Towers', 'category': 'Appetizers', 'calories': '560', 'fat': '38', 'carbs': '37', 'restaurant': "Applebee's"}
# {'name': 'Weight Watchers® Steak & Potato Salad', 'category': 'Salads', 'calories': '380', 'fat': '12', 'carbs': '32', 'restaurant': "Applebee's"}
# {'name': 'Add Grilled Shrimp', 'category': 'Sides', 'calories': '230', 'fat': '17', 'carbs': '2', 'restaurant': "Applebee's"}
# {'name': 'Applebee’s Reuben', 'category': 'Sandwiches', 'calories': '630', 'fat': '47', 'carbs': '25', 'restaurant': "Applebee's"}
# {'name': 'BBQ Pulled Pork Sliders', 'category': 'Burgers', 'calories': '1030', 'fat': '48', 'carbs': '90', 'restaurant': "Applebee's"}
# {'name': 'Bourbon Street Steak', 'category': 'Entrees', 'calories': '760', 'fat': '44', 'carbs': '35', 'restaurant': "Applebee's"}
# {'name': 'Caesar Salad', 'category': 'Salads', 'calories': '220', 'fat': '19', 'carbs': '8', 'restaurant': "Applebee's"}
# {'name': 'Cheeseburger Sliders add bacon', 'category': 'Burgers', 'calories': '1330', 'fat': '87', 'carbs': '83', 'restaurant': "Applebee's"}
# {'name': 'Chicken Noodle Soup', 'category': 'Soups', 'calories': '160', 'fat': '4', 'carbs': '17', 'restaurant': "Applebee's"}
# {'name': 'Chili Cheese Fries, Side', 'category': 'French Fries', 'calories': '550', 'fat': '33', 'carbs': '59', 'restaurant': "Applebee's"}
# {'name': 'Classic Wings, Hot Buffalo', 'category': 'Appetizers', 'calories': '720', 'fat': '49', 'carbs': '9', 'restaurant': "Applebee's"}
# {'name': 'Double-Glazed Baby Back Ribs', 'category': 'Ribs', 'calories': '1345', 'fat': '72', 'carbs': '95', 'restaurant': "Applebee's"}
# {'name': 'Fried Chicken Salad, Half', 'category': 'Salads', 'calories': '530', 'fat': '42', 'carbs': '26', 'restaurant': "Applebee's"}
# {'name': 'Grilled Chicken Caesar, Half', 'category': 'Salads', 'calories': '410', 'fat': '29', 'carbs': '12', 'restaurant': "Applebee's"}
# {'name': 'Grilled Shrimp ‘N Spinach Salad, Regular', 'category': 'Salads', 'calories': '1010', 'fat': '69', 'carbs': '63', 'restaurant': "Applebee's"}
# {'name': 'Hamburger', 'category': 'Burgers', 'calories': '790', 'fat': '46', 'carbs': '50', 'restaurant': "Applebee's"}
# {'name': 'Kids Applesauce side', 'category': "Kid's Meals", 'calories': '50', 'fat': '0', 'carbs': '27', 'restaurant': "Applebee's"}
# {'name': 'Kids Grilled Chicken Sandwich', 'category': "Kid's Meals", 'calories': '230', 'fat': '5', 'carbs': '23', 'restaurant': "Applebee's"}
# {'name': 'Kids OREO® Cookie Milkshake', 'category': "Kid's Meals", 'calories': '780', 'fat': '41', 'carbs': '97', 'restaurant': "Applebee's"}
# {'name': 'Maple Butter Blondie', 'category': 'Desserts', 'calories': '1100', 'fat': '63', 'carbs': '115', 'restaurant': "Applebee's"}
# {'name': 'Oriental Chicken Salad, Regular', 'category': 'Salads', 'calories': '1340', 'fat': '98', 'carbs': '85', 'restaurant': "Applebee's"}
# {'name': 'Pecan-Crusted Chicken Salad, Regular w/o dressing', 'category': 'Salads', 'calories': '880', 'fat': '46', 'carbs': '76', 'restaurant': "Applebee's"}
# {'name': 'Ribeye', 'category': 'Entrees', 'calories': '670', 'fat': '47', 'carbs': '3', 'restaurant': "Applebee's"}
# {'name': 'Shrimp Fettuccine Alfredo', 'category': 'Entrees', 'calories': '143', 'fat': '81', 'carbs': '113', 'restaurant': "Applebee's"}
# {'name': 'Sizzling Smokehouse Chicken Stack', 'category': 'Entrees', 'calories': '1170', 'fat': '59', 'carbs': '78', 'restaurant': "Applebee's"}
# {'name': 'Steak & Grilled Shrimp Combo', 'category': 'Entrees', 'calories': '540', 'fat': '36', 'carbs': '2', 'restaurant': "Applebee's"}
# {'name': 'Three-Cheese Chicken Penne', 'category': 'Entrees', 'calories': '1460', 'fat': '75', 'carbs': '127', 'restaurant': "Applebee's"}
# {'name': 'Trios Boneless Wings, Classic Buffalo', 'category': 'Appetizers', 'calories': '580', 'fat': '35', 'carbs': '33', 'restaurant': "Applebee's"}
# {'name': 'Trios Classic Wings, Hot Buffalo', 'category': 'Appetizers', 'calories': '360', 'fat': '25', 'carbs': '4', 'restaurant': "Applebee's"}
# {'name': 'Trios Wings Ranch Dipping Sauce', 'category': 'Appetizers', 'calories': '200', 'fat': '21', 'carbs': '1', 'restaurant': "Applebee's"}
# {'name': 'Wings Ranch Dipping Sauce', 'category': 'Appetizers', 'calories': '200', 'fat': '21', 'carbs': '1', 'restaurant': "Applebee's"}
# {'name': 'Add Fried Shrimp', 'category': 'Sides', 'calories': '390', 'fat': '21', 'carbs': '35', 'restaurant': "Applebee's"}
# {'name': 'Applebee’s Reuben', 'category': 'Sandwiches', 'calories': '1140', 'fat': '81', 'carbs': '49', 'restaurant': "Applebee's"}
# {'name': 'Baked Potato Soup', 'category': 'Soups', 'calories': '360', 'fat': '28', 'carbs': '20', 'restaurant': "Applebee's"}
# {'name': 'Bourbon Street Chicken & Shrimp', 'category': 'Entrees', 'calories': '750', 'fat': '45', 'carbs': '31', 'restaurant': "Applebee's"}
# {'name': 'Bruschetta Chicken Salad, Regular w/o dressing', 'category': 'Salads', 'calories': '790', 'fat': '36', 'carbs': '56', 'restaurant': "Applebee's"}
# {'name': 'Cheeseburger Sliders', 'category': 'Burgers', 'calories': '1270', 'fat': '82', 'carbs': '82', 'restaurant': "Applebee's"}
# {'name': 'Chicken Fried Steak (includes mashed potato, gravy & vegetable)', 'category': 'Entrees', 'calories': '1260', 'fat': '61', 'carbs': '118', 'restaurant': "Applebee's"}
# {'name': 'Chili', 'category': 'Soups', 'calories': '370', 'fat': '28', 'carbs': '16', 'restaurant': "Applebee's"}
# {'name': 'Classic Wings, Honey BBQ', 'category': 'Appetizers', 'calories': '790', 'fat': '35', 'carbs': '59', 'restaurant': "Applebee's"}
# {'name': 'Double Crunch Shrimp', 'category': 'Seafood', 'calories': '1280', 'fat': '69', 'carbs': '133', 'restaurant': "Applebee's"}
# {'name': 'Fried Chicken Salad', 'category': 'Salads', 'calories': '380', 'fat': '27', 'carbs': '20', 'restaurant': "Applebee's"}
# {'name': 'Garlic Mashed Potatoes', 'category': 'Sides', 'calories': '330', 'fat': '18', 'carbs': '38', 'restaurant': "Applebee's"}
# {'name': 'Grilled Shrimp ‘N Spinach Salad, Half w/o dressing', 'category': 'Salads', 'calories': '460', 'fat': '35', 'carbs': '12', 'restaurant': "Applebee's"}
# {'name': 'Grilled Steak Caesar, Regular w/o dressing', 'category': 'Salads', 'calories': '460', 'fat': '21', 'carbs': '21', 'restaurant': "Applebee's"}
# {'name': 'Kids Apple Juice (6.75 oz)', 'category': "Kid's Meals", 'calories': '70', 'fat': '0', 'carbs': '17', 'restaurant': "Applebee's"}
# {'name': 'Kids Grilled Cheese (sourdough bread)', 'category': "Kid's Meals", 'calories': '630', 'fat': '36', 'carbs': '54', 'restaurant': "Applebee's"}
# {'name': 'Kids Orange-Tangerine Juice (6.75 oz)', 'category': "Kid's Meals", 'calories': '70', 'fat': '0', 'carbs': '17', 'restaurant': "Applebee's"}
# {'name': 'Loaded Mashed Potatoes', 'category': 'Sides', 'calories': '550', 'fat': '42', 'carbs': '41', 'restaurant': "Applebee's"}
# {'name': 'Oriental Chicken Salad, Half w/o dressing', 'category': 'Salads', 'calories': '340', 'fat': '20', 'carbs': '25', 'restaurant': "Applebee's"}
# {'name': 'Pecan-Crusted Chicken Salad, Regular', 'category': 'Salads', 'calories': '1350', 'fat': '80', 'carbs': '114', 'restaurant': "Applebee's"}
# {'name': 'Red Beans & Rice', 'category': 'Sides', 'calories': '290', 'fat': '6', 'carbs': '48', 'restaurant': "Applebee's"}
# {'name': 'Shrimp ‘N Parmesan Sirloin', 'category': 'Entrees', 'calories': '660', 'fat': '42', 'carbs': '4', 'restaurant': "Applebee's"}
# {'name': 'Sizzling Skillet Fajitas - Steak', 'category': 'Entrees', 'calories': '1410', 'fat': '55', 'carbs': '152', 'restaurant': "Applebee's"}
# {'name': 'Steak & Fried Shrimp Combo', 'category': 'Entrees', 'calories': '650', 'fat': '34', 'carbs': '37', 'restaurant': "Applebee's"}
# {'name': 'Three-Cheese Chicken Penne', 'category': 'Entrees', 'calories': '940', 'fat': '49', 'carbs': '77', 'restaurant': "Applebee's"}
# {'name': 'Topper - Shrimp ‘N Parmesan', 'category': 'Sides', 'calories': '230', 'fat': '15', 'carbs': '4', 'restaurant': "Applebee's"}
# {'name': 'Trios Classic Wings, Honey BBQ', 'category': 'Appetizers', 'calories': '400', 'fat': '17', 'carbs': '29', 'restaurant': "Applebee's"}
# {'name': 'Trios Wings Bleu Cheese Dipping Sauce', 'category': 'Appetizers', 'calories': '240', 'fat': '26', 'carbs': '1', 'restaurant': "Applebee's"}
# {'name': 'Wings Bleu Cheese Dipping Sauce', 'category': 'Appetizers', 'calories': '240', 'fat': '26', 'carbs': '1', 'restaurant': "Applebee's"}
# {'name': 'Apple Walnut Chicken Salad, Half w/o dressing', 'category': 'Salads', 'calories': '350', 'fat': '20', 'carbs': '15', 'restaurant': "Applebee's"}
# {'name': 'Asiago Peppercorn Steak', 'category': 'Entrees', 'calories': '380', 'fat': '14', 'carbs': '25', 'restaurant': "Applebee's"}
# {'name': 'Blue Ribbon Brownie', 'category': 'Desserts', 'calories': '1310', 'fat': '63', 'carbs': '176', 'restaurant': "Applebee's"}
# {'name': 'Broccoli Cheddar Soup', 'category': 'Soups', 'calories': '280', 'fat': '23', 'carbs': '12', 'restaurant': "Applebee's"}
# {'name': 'California Shrimp Salad, Half w/o dressing', 'category': 'Salads', 'calories': '330', 'fat': '23', 'carbs': '14', 'restaurant': "Applebee's"}
# {'name': 'Chicken Broccoli Pasta Alfredo', 'category': 'Entrees', 'calories': '1350', 'fat': '72', 'carbs': '111', 'restaurant': "Applebee's"}
# {'name': 'Chicken Quesadilla Grande', 'category': 'Appetizers', 'calories': '1290', 'fat': '90', 'carbs': '90', 'restaurant': "Applebee's"}
# {'name': 'Chocolate Chip Cookie Sundae', 'category': 'Desserts', 'calories': '154', 'fat': '74', 'carbs': '210', 'restaurant': "Applebee's"}
# {'name': 'Cole Slaw', 'category': 'Sides', 'calories': '140', 'fat': '9', 'carbs': '15', 'restaurant': "Applebee's"}
# {'name': 'Fire Pit Bacon Burger', 'category': 'Burgers', 'calories': '1100', 'fat': '73', 'carbs': '53', 'restaurant': "Applebee's"}
# {'name': 'Fried Chicken Salad, Regular w/o dressing', 'category': 'Salads', 'calories': '540', 'fat': '42', 'carbs': '23', 'restaurant': "Applebee's"}
# {'name': 'Grilled Chicken Caesar, Regular w/o dressing', 'category': 'Salads', 'calories': '370', 'fat': '10', 'carbs': '21', 'restaurant': "Applebee's"}
# {'name': 'Honey BBQ Chicken Sandwich', 'category': 'Sandwiches', 'calories': '1000', 'fat': '42', 'carbs': '87', 'restaurant': "Applebee's"}
# {'name': 'Kids Chicken Tenders', 'category': "Kid's Meals", 'calories': '240', 'fat': '14', 'carbs': '11', 'restaurant': "Applebee's"}
# {'name': 'Kids Kraft Macaroni and Cheese', 'category': "Kid's Meals", 'calories': '300', 'fat': '9', 'carbs': '45', 'restaurant': "Applebee's"}
# {'name': 'Kids Steamed Broccoli Side', 'category': "Kid's Meals", 'calories': '30', 'fat': '0', 'carbs': '4', 'restaurant': "Applebee's"}
# {'name': 'New England Fish & Chips', 'category': 'Seafood', 'calories': '1930', 'fat': '138', 'carbs': '121', 'restaurant': "Applebee's"}
# {'name': 'Oriental Grilled Chicken Salad, Half', 'category': 'Salads', 'calories': '680', 'fat': '40', 'carbs': '55', 'restaurant': "Applebee's"}
# {'name': 'Potato Skins', 'category': 'Appetizers', 'calories': '1090', 'fat': '103', 'carbs': '66', 'restaurant': "Applebee's"}
# {'name': 'Santa Fe Chicken Salad', 'category': 'Salads', 'calories': '530', 'fat': '37', 'carbs': '28', 'restaurant': "Applebee's"}
# {'name': 'Sizzling Asian Shrimp', 'category': 'Entrees', 'calories': '850', 'fat': '33', 'carbs': '118', 'restaurant': "Applebee's"}
# {'name': 'Small Caesar Salad (with dressing)', 'category': 'Sides', 'calories': '310', 'fat': '27', 'carbs': '12', 'restaurant': "Applebee's"}
# {'name': 'Steak Quesadilla Towers', 'category': 'Appetizers', 'calories': '1110', 'fat': '73', 'carbs': '79', 'restaurant': "Applebee's"}
# {'name': 'Tomato Basil Soup', 'category': 'Soups', 'calories': '250', 'fat': '14', 'carbs': '28', 'restaurant': "Applebee's"}
# {'name': 'Trios Boneless Wings, Southern BBQ', 'category': 'Appetizers', 'calories': '550', 'fat': '28', 'carbs': '42', 'restaurant': "Applebee's"}
# {'name': 'Trios Grilled Chicken Wonton Tacos', 'category': 'Appetizers', 'calories': '430', 'fat': '18', 'carbs': '43', 'restaurant': "Applebee's"}
# {'name': 'Veggie Patch™ Pizza', 'category': 'Appetizers', 'calories': '930', 'fat': '67', 'carbs': '50', 'restaurant': "Applebee's"}
# {'name': 'Apple Walnut Chicken Salad, Regular', 'category': 'Salads', 'calories': '1030', 'fat': '67', 'carbs': '54', 'restaurant': "Applebee's"}
# {'name': 'Asiago Peppercorn Steak w/sides', 'category': 'Entrees', 'calories': '380', 'fat': '14', 'carbs': '25', 'restaurant': "Applebee's"}
# ...
# {'name': 'Small Mexican Rice (Available only with Platters)', 'category': 'Sides', 'calories': '235', 'fat': '6', 'carbs': '41', 'restaurant': 'Taco Bueno'}
# {'name': 'Potato Egg Taco', 'category': 'Breakfast Tacos', 'calories': '230', 'fat': '10', 'carbs': '24', 'restaurant': 'Taco Bueno'}
# {'name': 'Black Bean Burrito', 'category': 'Burritos', 'calories': '490', 'fat': '15', 'carbs': '70', 'restaurant': 'Taco Bueno'}
# {'name': 'Chicken Tortilla Soup - Bowl', 'category': 'Soups', 'calories': '237', 'fat': '11', 'carbs': '19', 'restaurant': 'Taco Bueno'}
# {'name': 'Chicken Taco Rollup™', 'category': 'Tacos', 'calories': '180', 'fat': '7', 'carbs': '18', 'restaurant': 'Taco Bueno'}
# {'name': 'Beef Quesadilla', 'category': 'Mexican Food', 'calories': '823', 'fat': '51', 'carbs': '49', 'restaurant': 'Taco Bueno'}
# {'name': 'BC Vegetarian Black Bean Burrito Without Sour Cream and cheese', 'category': 'Burritos', 'calories': '440', 'fat': '10', 'carbs': '71', 'restaurant': 'Taco Bueno'}
# {'name': 'Black Beans - Platter Portion', 'category': 'Sides', 'calories': '90', 'fat': '0', 'carbs': '18', 'restaurant': 'Taco Bueno'}
# {'name': 'Queso', 'category': 'Sides', 'calories': '279', 'fat': '21', 'carbs': '10', 'restaurant': 'Taco Bueno'}
# {'name': 'Meat Lovers Burrito', 'category': 'Breakfast Tacos', 'calories': '560', 'fat': '32', 'carbs': '37', 'restaurant': 'Taco Bueno'}
# {'name': 'Beef Muchaco®', 'category': 'Mexican Food', 'calories': '496', 'fat': '25', 'carbs': '49', 'restaurant': 'Taco Bueno'}
# {'name': 'Chicken Tortilla Soup - Cup', 'category': 'Soups', 'calories': '117', 'fat': '6', 'carbs': '11', 'restaurant': 'Taco Bueno'}
# {'name': 'Beef Bueno Chilada®', 'category': 'Entrees', 'calories': '523', 'fat': '32', 'carbs': '42', 'restaurant': 'Taco Bueno'}
# {'name': 'Chicken Quesadilla', 'category': 'Mexican Food', 'calories': '761', 'fat': '44', 'carbs': '50', 'restaurant': 'Taco Bueno'}
# {'name': 'BC Chicken Tortilla Soup- Bowl Without Tortilla Strips and cheese', 'category': 'Soups', 'calories': '148', 'fat': '6', 'carbs': '11', 'restaurant': 'Taco Bueno'}
# {'name': 'Refried Beans', 'category': 'Sides', 'calories': '634', 'fat': '34', 'carbs': '60', 'restaurant': 'Taco Bueno'}
# {'name': 'Bacon Egg Taco', 'category': 'Breakfast Tacos', 'calories': '240', 'fat': '13', 'carbs': '18', 'restaurant': 'Taco Bueno'}
# {'name': 'Party Burrito®', 'category': 'Burritos', 'calories': '374', 'fat': '18', 'carbs': '43', 'restaurant': 'Taco Bueno'}
# {'name': 'Chicken Nacho Salad', 'category': 'Salads', 'calories': '713', 'fat': '43', 'carbs': '59', 'restaurant': 'Taco Bueno'}
# {'name': 'Beef Taco Rollup™', 'category': 'Tacos', 'calories': '190', 'fat': '9', 'carbs': '18', 'restaurant': 'Taco Bueno'}
# {'name': 'Cheese Quesadilla', 'category': 'Mexican Food', 'calories': '709', 'fat': '42', 'carbs': '48', 'restaurant': 'Taco Bueno'}
# {'name': 'BC Steak Fajita Taco With Pico De Gallo (no cheese)', 'category': 'Tacos', 'calories': '210', 'fat': '9', 'carbs': '21', 'restaurant': 'Taco Bueno'}
# {'name': 'Black Beans - Side Portion', 'category': 'Sides', 'calories': '180', 'fat': '0', 'carbs': '36', 'restaurant': 'Taco Bueno'}
# {'name': 'Mexican Rice', 'category': 'Sides', 'calories': '469', 'fat': '12', 'carbs': '83', 'restaurant': 'Taco Bueno'}
# {'name': 'Sausage Egg Burrito', 'category': 'Breakfast Tacos', 'calories': '440', 'fat': '23', 'carbs': '37', 'restaurant': 'Taco Bueno'}
# {'name': 'Beef Potato Burrito', 'category': 'Burritos', 'calories': '358', 'fat': '21', 'carbs': '32', 'restaurant': 'Taco Bueno'}
# {'name': 'Chicken Taco Salad', 'category': 'Salads', 'calories': '838', 'fat': '57', 'carbs': '53', 'restaurant': 'Taco Bueno'}
# {'name': 'Flame-Grilled Chicken Fajita Taco', 'category': 'Tacos', 'calories': '210', 'fat': '8', 'carbs': '19', 'restaurant': 'Taco Bueno'}
# {'name': 'Chicken Mucho Nachos®', 'category': 'Mexican Food', 'calories': '1505', 'fat': '90', 'carbs': '128', 'restaurant': 'Taco Bueno'}
# {'name': 'BC Soft Beef Taco With Pico De Gallo (no cheese)', 'category': 'Tacos', 'calories': '200', 'fat': '9', 'carbs': '19', 'restaurant': 'Taco Bueno'}
# {'name': 'Chicken Taco Rollup™', 'category': "Kid's Meals", 'calories': '180', 'fat': '7', 'carbs': '18', 'restaurant': 'Taco Bueno'}
# {'name': 'Bacon Egg Burrito', 'category': 'Breakfast Tacos', 'calories': '490', 'fat': '26', 'carbs': '36', 'restaurant': 'Taco Bueno'}
# {'name': "Beef Big Ol' Burrito (B.O.B.™)", 'category': 'Burritos', 'calories': '772', 'fat': '46', 'carbs': '57', 'restaurant': 'Taco Bueno'}
# {'name': 'Chicken Muchaco®', 'category': 'Mexican Food', 'calories': '387', 'fat': '18', 'carbs': '40', 'restaurant': 'Taco Bueno'}
# {'name': 'Beef Soft Taco', 'category': 'Tacos', 'calories': '245', 'fat': '14', 'carbs': '18', 'restaurant': 'Taco Bueno'}
# {'name': 'Cheesecake Chimichanga', 'category': 'Desserts', 'calories': '210', 'fat': '11', 'carbs': '24', 'restaurant': 'Taco Bueno'}
# {'name': 'BC Chicken Fajita Taco With Pico De Gallo (no cheese)', 'category': 'Tacos', 'calories': '190', 'fat': '6', 'carbs': '20', 'restaurant': 'Taco Bueno'}
# {'name': 'Kids Cheese Quesadilla', 'category': "Kid's Meals", 'calories': '219', 'fat': '11', 'carbs': '23', 'restaurant': 'Taco Bueno'}
# {'name': 'Strawberry', 'category': 'Shakes', 'calories': '195', 'fat': '0', 'carbs': '51', 'restaurant': 'Taco Bueno'}
# {'name': 'Meat Lovers Taco', 'category': 'Breakfast Tacos', 'calories': '310', 'fat': '20', 'carbs': '19', 'restaurant': 'Taco Bueno'}
# {'name': "Chicken Big Ol' Burrito (B.O.B.™)", 'category': 'Burritos', 'calories': '607', 'fat': '30', 'carbs': '53', 'restaurant': 'Taco Bueno'}
# {'name': 'Muchaco Without Cheddar Cheese', 'category': 'Mexican Food', 'calories': '348', 'fat': '14', 'carbs': '39', 'restaurant': 'Taco Bueno'}
# {'name': 'Chicken Soft Taco', 'category': 'Tacos', 'calories': '184', 'fat': '8', 'carbs': '19', 'restaurant': 'Taco Bueno'}
# {'name': 'MexiDips & Chips®', 'category': 'Sides', 'calories': '1086', 'fat': '62', 'carbs': '105', 'restaurant': 'Taco Bueno'}
# {'name': 'BC Crispy Beef Taco With Pico De Gallo (no cheese)', 'category': 'Tacos', 'calories': '170', 'fat': '9', 'carbs': '12', 'restaurant': 'Taco Bueno'}
# {'name': 'Party Burrito®', 'category': "Kid's Meals", 'calories': '374', 'fat': '18', 'carbs': '43', 'restaurant': 'Taco Bueno'}
# {'name': 'Strawberry', 'category': 'Shakes', 'calories': '325', 'fat': '0', 'carbs': '85', 'restaurant': 'Taco Bueno'}
# {'name': 'Potato Stix', 'category': 'Breakfast Tacos', 'calories': '280', 'fat': '22', 'carbs': '18', 'restaurant': 'Taco Bueno'}
# {'name': 'Combination Burrito', 'category': 'Burritos', 'calories': '564', 'fat': '29', 'carbs': '54', 'restaurant': 'Taco Bueno'}
# {'name': 'Beef Taco Salad', 'category': 'Salads', 'calories': '1043', 'fat': '75', 'carbs': '58', 'restaurant': 'Taco Bueno'}
# {'name': 'Party Taco®', 'category': 'Tacos', 'calories': '143', 'fat': '10', 'carbs': '5', 'restaurant': 'Taco Bueno'}
# {'name': 'Beef Mucho Nachos®', 'category': 'Mexican Food', 'calories': '1567', 'fat': '97', 'carbs': '127', 'restaurant': 'Taco Bueno'}
# {'name': 'BC Crispy Chicken Taco With Pico De Gallo (no cheese)', 'category': 'Tacos', 'calories': '150', 'fat': '6', 'carbs': '12', 'restaurant': 'Taco Bueno'}
# {'name': 'Beef Taco Rollup™', 'category': "Kid's Meals", 'calories': '190', 'fat': '9', 'carbs': '18', 'restaurant': 'Taco Bueno'}
# {'name': 'Bacon Egg Quesadilla', 'category': 'Breakfast', 'calories': '910', 'fat': '59', 'carbs': '51', 'restaurant': 'Taco Bueno'}
# {'name': 'Son of Baconator®', 'category': 'Burgers', 'calories': '670', 'fat': '37', 'carbs': '41', 'restaurant': "Wendy's"}
# {'name': '6-piece Chicken Nuggets', 'category': 'Chicken', 'calories': '270', 'fat': '18', 'carbs': '14', 'restaurant': "Wendy's"}
# {'name': 'Small French Fries', 'category': 'French Fries', 'calories': '310', 'fat': '15', 'carbs': '40', 'restaurant': "Wendy's"}
# {'name': 'Spicy Chicken Caesar Salad', 'category': 'Salads', 'calories': '780', 'fat': '51', 'carbs': '40', 'restaurant': "Wendy's"}
# {'name': 'Small Original Chocolate Frosty™', 'category': 'Shakes', 'calories': '290', 'fat': '7', 'carbs': '48', 'restaurant': "Wendy's"}
# {'name': 'Large Vanilla Frosty™', 'category': 'Shakes', 'calories': '560', 'fat': '14', 'carbs': '93', 'restaurant': "Wendy's"}
# {'name': 'Vanilla Frosty Waffle Cone', 'category': 'Shakes', 'calories': '290', 'fat': '6', 'carbs': '53', 'restaurant': "Wendy's"}
# {'name': 'Double Stack™', 'category': 'Burgers', 'calories': '460', 'fat': '25', 'carbs': '27', 'restaurant': "Wendy's"}
# {'name': 'Jr. Cheeseburger', 'category': 'Burgers', 'calories': '290', 'fat': '13', 'carbs': '26', 'restaurant': "Wendy's"}
# {'name': 'Apple Slices', 'category': 'Desserts', 'calories': '40', 'fat': '0', 'carbs': '9', 'restaurant': "Wendy's"}
# {'name': 'Asian Cashew Chicken Salad', 'category': 'Salads', 'calories': '380', 'fat': '13', 'carbs': '33', 'restaurant': "Wendy's"}
# {'name': 'Jr. Cheeseburger Deluxe', 'category': 'Burgers', 'calories': '350', 'fat': '19', 'carbs': '28', 'restaurant': "Wendy's"}
# {'name': '10-piece Chicken Nuggets', 'category': 'Chicken', 'calories': '450', 'fat': '30', 'carbs': '24', 'restaurant': "Wendy's"}
# {'name': 'Large French Fries', 'category': 'French Fries', 'calories': '500', 'fat': '24', 'carbs': '65', 'restaurant': "Wendy's"}
# {'name': 'Garden Side Salad', 'category': 'Salads', 'calories': '200', 'fat': '13', 'carbs': '19', 'restaurant': "Wendy's"}
# {'name': 'Bacon Cheese Potato', 'category': 'Sides', 'calories': '540', 'fat': '21', 'carbs': '66', 'restaurant': "Wendy's"}
# {'name': 'Jr. Hamburger', 'category': 'Burgers', 'calories': '260', 'fat': '10', 'carbs': '25', 'restaurant': "Wendy's"}
# {'name': '10-piece Spicy Chicken Nuggets', 'category': 'Chicken', 'calories': '430', 'fat': '28', 'carbs': '23', 'restaurant': "Wendy's"}
# {'name': 'Chili Cheese Fries', 'category': 'French Fries', 'calories': '530', 'fat': '28', 'carbs': '55', 'restaurant': "Wendy's"}
# {'name': 'Caesar Side Salad', 'category': 'Salads', 'calories': '250', 'fat': '17', 'carbs': '18', 'restaurant': "Wendy's"}
# {'name': 'Crispy Chicken Caesar Wrap', 'category': 'Wraps', 'calories': '410', 'fat': '24', 'carbs': '31', 'restaurant': "Wendy's"}
# {'name': 'JBC (Jr. Bacon Cheeseburger)', 'category': 'Burgers', 'calories': '390', 'fat': '22', 'carbs': '26', 'restaurant': "Wendy's"}
# {'name': '6-piece Spicy Chicken Nuggets', 'category': 'Chicken', 'calories': '260', 'fat': '17', 'carbs': '14', 'restaurant': "Wendy's"}
# {'name': 'Medium French Fries', 'category': 'French Fries', 'calories': '410', 'fat': '20', 'carbs': '52', 'restaurant': "Wendy's"}
# {'name': 'Spicy Chicken Caesar Salad Half-Size', 'category': 'Salads', 'calories': '440', 'fat': '27', 'carbs': '28', 'restaurant': "Wendy's"}
# {'name': 'Broccoli Cheese Potato', 'category': 'Sides', 'calories': '440', 'fat': '14', 'carbs': '67', 'restaurant': "Wendy's"}
# {'name': 'Small Strawberry Frosty™ Shake', 'category': 'Shakes', 'calories': '540', 'fat': '12', 'carbs': '97', 'restaurant': "Wendy's"}
# {'name': 'Chocolate Frosty Waffle Cone', 'category': 'Shakes', 'calories': '300', 'fat': '6', 'carbs': '54', 'restaurant': "Wendy's"}
# {'name': 'Baconator®', 'category': 'Burgers', 'calories': '940', 'fat': '56', 'carbs': '41', 'restaurant': "Wendy's"}
# {'name': '4-piece Spicy Chicken Nuggets', 'category': 'Chicken', 'calories': '170', 'fat': '11', 'carbs': '9', 'restaurant': "Wendy's"}
# {'name': 'Value French Fries', 'category': 'French Fries', 'calories': '220', 'fat': '11', 'carbs': '28', 'restaurant': "Wendy's"}
# {'name': 'Apple Pecan Chicken Salad Half-Size', 'category': 'Salads', 'calories': '340', 'fat': '18', 'carbs': '28', 'restaurant': "Wendy's"}
# {'name': 'Premium Cod Fillet Sandwich', 'category': 'Sandwiches', 'calories': '480', 'fat': '23', 'carbs': '51', 'restaurant': "Wendy's"}
# {'name': 'Medium Vanilla Frosty™', 'category': 'Shakes', 'calories': '390', 'fat': '10', 'carbs': '65', 'restaurant': "Wendy's"}
# {'name': 'Large Caramel Frosty™ Shake', 'category': 'Shakes', 'calories': '990', 'fat': '18', 'carbs': '195', 'restaurant': "Wendy's"}
# {'name': "Dave's Hot 'N Juicy™ 1/4 lb.* Single", 'category': 'Burgers', 'calories': '580', 'fat': '31', 'carbs': '42', 'restaurant': "Wendy's"}
# {'name': "Kids' Cheeseburger", 'category': 'Burgers', 'calories': '290', 'fat': '13', 'carbs': '26', 'restaurant': "Wendy's"}
# {'name': 'Large Chili', 'category': 'Entrees', 'calories': '270', 'fat': '8', 'carbs': '31', 'restaurant': "Wendy's"}
# {'name': 'BBQ Ranch Chicken Salad', 'category': 'Salads', 'calories': '580', 'fat': '29', 'carbs': '43', 'restaurant': "Wendy's"}
# {'name': 'Homestyle Chicken Fillet', 'category': 'Sandwiches', 'calories': '510', 'fat': '20', 'carbs': '54', 'restaurant': "Wendy's"}
# {'name': 'Jr. Original Chocolate Frosty™', 'category': 'Shakes', 'calories': '200', 'fat': '5', 'carbs': '32', 'restaurant': "Wendy's"}
# {'name': 'Medium Original Chocolate Frosty™', 'category': 'Shakes', 'calories': '410', 'fat': '10', 'carbs': '67', 'restaurant': "Wendy's"}
# {'name': "Dave's Hot 'N Juicy™ 1/2 lb.* Double", 'category': 'Burgers', 'calories': '820', 'fat': '47', 'carbs': '42', 'restaurant': "Wendy's"}
# {'name': "Kids' Hamburger", 'category': 'Burgers', 'calories': '250', 'fat': '10', 'carbs': '25', 'restaurant': "Wendy's"}
# {'name': 'Value French Fries', 'category': 'French Fries', 'calories': '220', 'fat': '11', 'carbs': '28', 'restaurant': "Wendy's"}
# {'name': 'BBQ Ranch Chicken Salad, Half Size', 'category': 'Salads', 'calories': '310', 'fat': '14', 'carbs': '25', 'restaurant': "Wendy's"}
# {'name': 'Ultimate Chicken Grill', 'category': 'Sandwiches', 'calories': '370', 'fat': '7', 'carbs': '43', 'restaurant': "Wendy's"}
# {'name': 'Large Original Chocolate Frosty™', 'category': 'Shakes', 'calories': '590', 'fat': '15', 'carbs': '97', 'restaurant': "Wendy's"}
# {'name': 'Large Chocolate Frosty™ Shake', 'category': 'Shakes', 'calories': '870', 'fat': '17', 'carbs': '164', 'restaurant': "Wendy's"}
# {'name': "Dave's Hot 'N Juicy™ 3/4 lb.* Triple", 'category': 'Burgers', 'calories': '1090', 'fat': '66', 'carbs': '43', 'restaurant': "Wendy's"}
# {'name': '4-piece Chicken Nuggets', 'category': 'Chicken', 'calories': '180', 'fat': '12', 'carbs': '10', 'restaurant': "Wendy's"}
# {'name': "Kids' French Fries", 'category': 'French Fries', 'calories': '220', 'fat': '11', 'carbs': '28', 'restaurant': "Wendy's"}
# {'name': 'Apple Pecan Chicken Salad', 'category': 'Salads', 'calories': '570', 'fat': '27', 'carbs': '49', 'restaurant': "Wendy's"}
# {'name': 'Crispy Chicken Sandwich', 'category': 'Sandwiches', 'calories': '350', 'fat': '19', 'carbs': '34', 'restaurant': "Wendy's"}
# {'name': 'Small Vanilla Frosty™', 'category': 'Shakes', 'calories': '280', 'fat': '7', 'carbs': '46', 'restaurant': "Wendy's"}
# {'name': 'Small Caramel Frosty™ Shake', 'category': 'Shakes', 'calories': '650', 'fat': '14', 'carbs': '121', 'restaurant': "Wendy's"}
# {'name': 'Small Chili', 'category': 'Entrees', 'calories': '180', 'fat': '5', 'carbs': '20', 'restaurant': "Wendy's"}
# {'name': 'Asian Cashew Chicken Salad, Half-Size', 'category': 'Salads', 'calories': '240', 'fat': '10', 'carbs': '20', 'restaurant': "Wendy's"}
# {'name': 'Spicy Chicken Sandwich', 'category': 'Sandwiches', 'calories': '510', 'fat': '20', 'carbs': '55', 'restaurant': "Wendy's"}
# {'name': 'Jr. Original Chocolate Frosty™', 'category': 'Shakes', 'calories': '200', 'fat': '5', 'carbs': '32', 'restaurant': "Wendy's"}
# {'name': 'Grilled Chicken Go Wrap', 'category': 'Wraps', 'calories': '260', 'fat': '10', 'carbs': '25', 'restaurant': "Wendy's"}
# {'name': 'Asiago Ranch Chicken Club', 'category': 'Sandwiches', 'calories': '670', 'fat': '32', 'carbs': '57', 'restaurant': "Wendy's"}
# {'name': 'Spicy Chicken Go Wrap', 'category': 'Wraps', 'calories': '330', 'fat': '16', 'carbs': '30', 'restaurant': "Wendy's"}
# {'name': 'Large Strawberry Frosty™ Shake', 'category': 'Shakes', 'calories': '780', 'fat': '15', 'carbs': '149', 'restaurant': "Wendy's"}

# %%
foods
# Out:
# [{'name': 'Original Bacon Double Cheeseburger',
#   'category': 'Burgers',
#   'calories': '760',
#   'fat': '45',
#   'carbs': '45',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Coney (Chili) Dog',
#   'category': 'Entrees',
#   'calories': '340',
#   'fat': '20',
#   'carbs': '26',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Chili Fries',
#   'category': 'French Fries',
#   'calories': '370',
#   'fat': '15',
#   'carbs': '49',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Strawberry Milkshake (small)',
#   'category': 'Shakes',
#   'calories': '670',
#   'fat': '29',
#   'carbs': '90',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'A&W® Root Beer Freeze (large)',
#   'category': 'Shakes',
#   'calories': '820',
#   'fat': '18',
#   'carbs': '150',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Caramel Sundae',
#   'category': 'Desserts',
#   'calories': '340',
#   'fat': '9',
#   'carbs': '57',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Strawberry Banana Smoothee',
#   'category': 'Shakes',
#   'calories': '420',
#   'fat': '6',
#   'carbs': '86',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Chocolate Fudge Blendrrr',
#   'category': 'Desserts',
#   'calories': '1010',
#   'fat': '59',
#   'carbs': '152',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Strawberry Limeade',
#   'category': 'Drinks',
#   'calories': '420',
#   'fat': '0',
#   'carbs': '105',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Watermelon Slushee',
#   'category': 'Drinks',
#   'calories': '270',
#   'fat': '0',
#   'carbs': '73',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Lime Slushee',
#   'category': 'Drinks',
#   'calories': '480',
#   'fat': '0',
#   'carbs': '119',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'A&W® Root Beer',
#   'category': 'Drinks',
#   'calories': '880',
#   'fat': '0',
#   'carbs': '232',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Cheeseburger',
#   'category': 'Burgers',
#   'calories': '420',
#   'fat': '21',
#   'carbs': '37',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'French Fries (Regular)',
#   'category': 'French Fries',
#   'calories': '310',
#   'fat': '12',
#   'carbs': '45',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Cheese Curds (Large)',
#   'category': 'Sides',
#   'calories': '1140',
#   'fat': '80',
#   'carbs': '54',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Chocolate Milkshake (small)',
#   'category': 'Shakes',
#   'calories': '700',
#   'fat': '29',
#   'carbs': '100',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Orange Freeze (small)',
#   'category': 'Shakes',
#   'calories': '450',
#   'fat': '8',
#   'carbs': '108',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'A&W® Diet Root Beer Float (small)',
#   'category': 'Shakes',
#   'calories': '170',
#   'fat': '5',
#   'carbs': '30',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Strawberry Smoothee',
#   'category': 'Shakes',
#   'calories': '610',
#   'fat': '10',
#   'carbs': '121',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Limeade',
#   'category': 'Drinks',
#   'calories': '140',
#   'fat': '0',
#   'carbs': '38',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Cherry Limeade',
#   'category': 'Drinks',
#   'calories': '340',
#   'fat': '0',
#   'carbs': '90',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Lemon Slushee',
#   'category': 'Drinks',
#   'calories': '330',
#   'fat': '0',
#   'carbs': '82',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Blue Raspberry Slushee',
#   'category': 'Drinks',
#   'calories': '570',
#   'fat': '0',
#   'carbs': '142',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'A&W® Diet Root Beer',
#   'category': 'Drinks',
#   'calories': '0',
#   'fat': '0',
#   'carbs': '0',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Grilled Chicken Sandwich',
#   'category': 'Chicken',
#   'calories': '400',
#   'fat': '15',
#   'carbs': '31',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'French Fries (Large)',
#   'category': 'French Fries',
#   'calories': '430',
#   'fat': '17',
#   'carbs': '61',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Chili',
#   'category': 'Sides',
#   'calories': '190',
#   'fat': '6',
#   'carbs': '22',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Chocolate Milkshake (medium)',
#   'category': 'Shakes',
#   'calories': '880',
#   'fat': '36',
#   'carbs': '125',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Orange Freeze (medium)',
#   'category': 'Shakes',
#   'calories': '600',
#   'fat': '10',
#   'carbs': '142',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'A&W® Diet Root Beer Float (medium)',
#   'category': 'Shakes',
#   'calories': '170',
#   'fat': '5',
#   'carbs': '30',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Orange Float (large)',
#   'category': 'Shakes',
#   'calories': '610',
#   'fat': '9',
#   'carbs': '137',
#   'restaurant': 'A&W Restaurants'},
#  {'name': "Reese's® Peanut Butter Fudge Blendrrr",
#   'category': 'Desserts',
#   'calories': '700',
#   'fat': '41',
#   'carbs': '103',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Limeade',
#   'category': 'Drinks',
#   'calories': '210',
#   'fat': '0',
#   'carbs': '55',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Cherry Limeade',
#   'category': 'Drinks',
#   'calories': '530',
#   'fat': '0',
#   'carbs': '138',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Lemon Slushee',
#   'category': 'Drinks',
#   'calories': '440',
#   'fat': '0',
#   'carbs': '110',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Blue Raspberry Slushee',
#   'category': 'Drinks',
#   'calories': '740',
#   'fat': '0',
#   'carbs': '182',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'A&W® Diet Root Beer',
#   'category': 'Drinks',
#   'calories': '0',
#   'fat': '0',
#   'carbs': '0',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Original Double Cheeseburger',
#   'category': 'Burgers',
#   'calories': '680',
#   'fat': '38',
#   'carbs': '44',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Coney (Chili) Cheese Dog',
#   'category': 'Entrees',
#   'calories': '380',
#   'fat': '23',
#   'carbs': '28',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Breaded Onion Rings (Regular)',
#   'category': 'Sides',
#   'calories': '350',
#   'fat': '16',
#   'carbs': '45',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Strawberry Milkshake (medium)',
#   'category': 'Shakes',
#   'calories': '840',
#   'fat': '36',
#   'carbs': '113',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'A&W® Diet Root Beer Freeze (small)',
#   'category': 'Shakes',
#   'calories': '260',
#   'fat': '8',
#   'carbs': '39',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'A&W® Root Beer Float (small)',
#   'category': 'Shakes',
#   'calories': '330',
#   'fat': '5',
#   'carbs': '70',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Strawberry Banana Smoothee',
#   'category': 'Shakes',
#   'calories': '680',
#   'fat': '10',
#   'carbs': '137',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Oreo® Cookies & Cream Blendrrr',
#   'category': 'Desserts',
#   'calories': '340',
#   'fat': '12',
#   'carbs': '56',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Strawberry Limeade',
#   'category': 'Drinks',
#   'calories': '560',
#   'fat': '0',
#   'carbs': '143',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Watermelon Slushee',
#   'category': 'Drinks',
#   'calories': '360',
#   'fat': '0',
#   'carbs': '99',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Lime Slushee',
#   'category': 'Drinks',
#   'calories': '770',
#   'fat': '0',
#   'carbs': '188',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'A&W® Root Beer',
#   'category': 'Drinks',
#   'calories': '1760',
#   'fat': '0',
#   'carbs': '464',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Papa Single Burger',
#   'category': 'Burgers',
#   'calories': '470',
#   'fat': '25',
#   'carbs': '38',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Hot Dog (plain)',
#   'category': 'Entrees',
#   'calories': '310',
#   'fat': '19',
#   'carbs': '23',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Cheese Fries',
#   'category': 'French Fries',
#   'calories': '390',
#   'fat': '18',
#   'carbs': '50',
#   'restaurant': 'A&W Restaurants'},
#  {'name': "Reese's® Polar Swirl®",
#   'category': 'Desserts',
#   'calories': '740',
#   'fat': '31',
#   'carbs': '97',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'A&W® Root Beer Freeze (medium)',
#   'category': 'Shakes',
#   'calories': '480',
#   'fat': '10',
#   'carbs': '89',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Hot Fudge Sundae',
#   'category': 'Desserts',
#   'calories': '350',
#   'fat': '11',
#   'carbs': '54',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Strawberry Banana Smoothee',
#   'category': 'Shakes',
#   'calories': '390',
#   'fat': '6',
#   'carbs': '78',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Chocolate Fudge Blendrrr',
#   'category': 'Desserts',
#   'calories': '560',
#   'fat': '32',
#   'carbs': '92',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Strawberry Limeade',
#   'category': 'Drinks',
#   'calories': '290',
#   'fat': '0',
#   'carbs': '75',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Cherry Slushee',
#   'category': 'Drinks',
#   'calories': '900',
#   'fat': '0',
#   'carbs': '224',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Lime Slushee',
#   'category': 'Drinks',
#   'calories': '380',
#   'fat': '0',
#   'carbs': '94',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'A&W® Root Beer',
#   'category': 'Drinks',
#   'calories': '440',
#   'fat': '0',
#   'carbs': '116',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Original Bacon Cheeseburger',
#   'category': 'Burgers',
#   'calories': '530',
#   'fat': '30',
#   'carbs': '39',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Cheese Dog',
#   'category': 'Entrees',
#   'calories': '350',
#   'fat': '22',
#   'carbs': '26',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Breaded Onion Rings (Large)',
#   'category': 'Sides',
#   'calories': '480',
#   'fat': '27',
#   'carbs': '62',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Vanilla Milkshake (small)',
#   'category': 'Shakes',
#   'calories': '720',
#   'fat': '31',
#   'carbs': '97',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'A&W® Diet Root Beer Freeze (medium)',
#   'category': 'Shakes',
#   'calories': '340',
#   'fat': '10',
#   'carbs': '53',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'A&W® Root Beer Float (medium)',
#   'category': 'Shakes',
#   'calories': '350',
#   'fat': '5',
#   'carbs': '77',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Strawberry Smoothee',
#   'category': 'Shakes',
#   'calories': '360',
#   'fat': '6',
#   'carbs': '70',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Oreo® Cookies & Cream Blendrrr',
#   'category': 'Desserts',
#   'calories': '430',
#   'fat': '15',
#   'carbs': '72',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Cherry Limeade',
#   'category': 'Drinks',
#   'calories': '190',
#   'fat': '0',
#   'carbs': '51',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Watermelon Slushee',
#   'category': 'Drinks',
#   'calories': '460',
#   'fat': '0',
#   'carbs': '124',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Blue Raspberry Slushee',
#   'category': 'Drinks',
#   'calories': '270',
#   'fat': '0',
#   'carbs': '67',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'A&W® Diet Root Beer',
#   'category': 'Drinks',
#   'calories': '0',
#   'fat': '0',
#   'carbs': '0',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Hamburger',
#   'category': 'Burgers',
#   'calories': '380',
#   'fat': '19',
#   'carbs': '33',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'French Fries (Small/ Kids)',
#   'category': 'French Fries',
#   'calories': '200',
#   'fat': '8',
#   'carbs': '28',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Cheese Curds (Regular)',
#   'category': 'Sides',
#   'calories': '570',
#   'fat': '40',
#   'carbs': '27',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Vanilla Milkshake (medium',
#   'category': 'Shakes',
#   'calories': '900',
#   'fat': '39',
#   'carbs': '121',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'A&W® Diet Root Beer Freeze (large)',
#   'category': 'Shakes',
#   'calories': '600',
#   'fat': '18',
#   'carbs': '92',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'A&W® Root Beer Float (large)',
#   'category': 'Shakes',
#   'calories': '640',
#   'fat': '10',
#   'carbs': '136',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Strawberry Smoothee',
#   'category': 'Shakes',
#   'calories': '370',
#   'fat': '6',
#   'carbs': '74',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Oreo® Cookies & Cream Blendrrr',
#   'category': 'Desserts',
#   'calories': '650',
#   'fat': '21',
#   'carbs': '109',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Cherry Limeade',
#   'category': 'Drinks',
#   'calories': '300',
#   'fat': '0',
#   'carbs': '79',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Watermelon Slushee',
#   'category': 'Drinks',
#   'calories': '720',
#   'fat': '0',
#   'carbs': '197',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Blue Raspberry Slushee',
#   'category': 'Drinks',
#   'calories': '370',
#   'fat': '0',
#   'carbs': '91',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'A&W® Diet Root Beer',
#   'category': 'Drinks',
#   'calories': '0',
#   'fat': '0',
#   'carbs': '0',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Chicken Strips- 3 pieces',
#   'category': 'Chicken',
#   'calories': '500',
#   'fat': '29',
#   'carbs': '32',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Corn Dog Nuggets® (Regular)',
#   'category': 'Sides',
#   'calories': '280',
#   'fat': '13',
#   'carbs': '32',
#   'restaurant': 'A&W Restaurants'},
#  {'name': "M&M's® Polar Swirl®",
#   'category': 'Desserts',
#   'calories': '710',
#   'fat': '25',
#   'carbs': '107',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Vanilla Cone (large)',
#   'category': 'Desserts',
#   'calories': '260',
#   'fat': '7',
#   'carbs': '41',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Strawberry Sundae',
#   'category': 'Desserts',
#   'calories': '300',
#   'fat': '8',
#   'carbs': '47',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Pineapple Banana Smoothee',
#   'category': 'Shakes',
#   'calories': '480',
#   'fat': '6',
#   'carbs': '104',
#   'restaurant': 'A&W Restaurants'},
#  {'name': "Reese's® Peanut Butter Fudge Blendrrr",
#   'category': 'Desserts',
#   'calories': '1360',
#   'fat': '79',
#   'carbs': '203',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Limeade',
#   'category': 'Drinks',
#   'calories': '390',
#   'fat': '0',
#   'carbs': '103',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Cherry Slushee',
#   'category': 'Drinks',
#   'calories': '450',
#   'fat': '0',
#   'carbs': '112',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Lemon Slushee',
#   'category': 'Drinks',
#   'calories': '890',
#   'fat': '0',
#   'carbs': '221',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'A&W® Root Beer',
#   'category': 'Drinks',
#   'calories': '220',
#   'fat': '0',
#   'carbs': '58',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'A&W® Diet Root Beer',
#   'category': 'Drinks',
#   'calories': '0',
#   'fat': '0',
#   'carbs': '0',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Crispy Chicken Sandwich',
#   'category': 'Chicken',
#   'calories': '550',
#   'fat': '25',
#   'carbs': '52',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Corn Dog Nuggets® (Small/ Kids)',
#   'category': 'Sides',
#   'calories': '180',
#   'fat': '8',
#   'carbs': '20',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Extra Burger Patty',
#   'category': 'Sides',
#   'calories': '170',
#   'fat': '12',
#   'carbs': '2',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Vanilla Cone (regular)',
#   'category': 'Desserts',
#   'calories': '200',
#   'fat': '5',
#   'carbs': '32',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Orange Freeze (medium)',
#   'category': 'Shakes',
#   'calories': '970',
#   'fat': '18',
#   'carbs': '223',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'A&W® Diet Root Beer Float (large)',
#   'category': 'Shakes',
#   'calories': '350',
#   'fat': '10',
#   'carbs': '60',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Pineapple Banana Smoothee',
#   'category': 'Shakes',
#   'calories': '400',
#   'fat': '6',
#   'carbs': '85',
#   'restaurant': 'A&W Restaurants'},
#  {'name': "Reese's® Peanut Butter Fudge Blendrrr",
#   'category': 'Desserts',
#   'calories': '710',
#   'fat': '41',
#   'carbs': '108',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Limeade',
#   'category': 'Drinks',
#   'calories': '250',
#   'fat': '0',
#   'carbs': '66',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Cherry Slushee',
#   'category': 'Drinks',
#   'calories': '330',
#   'fat': '0',
#   'carbs': '83',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Lemon Slushee',
#   'category': 'Drinks',
#   'calories': '560',
#   'fat': '0',
#   'carbs': '139',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'A&W® Root Beer',
#   'category': 'Drinks',
#   'calories': '160',
#   'fat': '0',
#   'carbs': '43',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'A&W® Diet Root Beer',
#   'category': 'Drinks',
#   'calories': '0',
#   'fat': '0',
#   'carbs': '0',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Papa Burger®',
#   'category': 'Burgers',
#   'calories': '690',
#   'fat': '39',
#   'carbs': '44',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Crunchy Shrimp',
#   'category': 'Seafood',
#   'calories': '340',
#   'fat': '19',
#   'carbs': '34',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Chili Cheese Fries',
#   'category': 'French Fries',
#   'calories': '410',
#   'fat': '17',
#   'carbs': '52',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Oreo® Polar Swirl®',
#   'category': 'Desserts',
#   'calories': '690',
#   'fat': '24',
#   'carbs': '107',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'A&W® Root Beer Freeze (small)',
#   'category': 'Shakes',
#   'calories': '370',
#   'fat': '8',
#   'carbs': '68',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Chocolate Sundae',
#   'category': 'Desserts',
#   'calories': '320',
#   'fat': '8',
#   'carbs': '53',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Pineapple Banana Smoothee',
#   'category': 'Shakes',
#   'calories': '750',
#   'fat': '10',
#   'carbs': '160',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Chocolate Fudge Blendrrr',
#   'category': 'Desserts',
#   'calories': '490',
#   'fat': '30',
#   'carbs': '68',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Strawberry Limeade',
#   'category': 'Drinks',
#   'calories': '230',
#   'fat': '0',
#   'carbs': '58',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Cherry Slushee',
#   'category': 'Drinks',
#   'calories': '570',
#   'fat': '0',
#   'carbs': '141',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Lime Slushee',
#   'category': 'Drinks',
#   'calories': '280',
#   'fat': '0',
#   'carbs': '69',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'A&W® Root Beer',
#   'category': 'Drinks',
#   'calories': '270',
#   'fat': '0',
#   'carbs': '72',
#   'restaurant': 'A&W Restaurants'},
#  {'name': 'Applebee’s House Salad (without dressing)',
#   'category': 'Salads',
#   'calories': '180',
#   'fat': '15',
#   'carbs': '12',
#   'restaurant': "Applebee's"},
#  {'name': 'Baked Potato',
#   'category': 'Sides',
#   'calories': '430',
#   'fat': '28',
#   'carbs': '42',
#   'restaurant': "Applebee's"},
#  {'name': 'Boneless Wings, Southern BBQ',
#   'category': 'Appetizers',
#   'calories': '1110',
#   'fat': '55',
#   'carbs': '83',
#   'restaurant': "Applebee's"},
#  {'name': 'Bruschetta Chicken Salad, Half w/o dressing',
#   'category': 'Salads',
#   'calories': '580',
#   'fat': '30',
#   'carbs': '40',
#   'restaurant': "Applebee's"},
#  {'name': 'Cheese Quesadilla Grande',
#   'category': 'Appetizers',
#   'calories': '1130',
#   'fat': '87',
#   'carbs': '85',
#   'restaurant': "Applebee's"},
#  {'name': 'Chicken Fettuccine Carbonara',
#   'category': 'Entrees',
#   'calories': '1440',
#   'fat': '82',
#   'carbs': '107',
#   'restaurant': "Applebee's"},
#  {'name': 'Chicken Tortilla Soup',
#   'category': 'Soups',
#   'calories': '140',
#   'fat': '7',
#   'carbs': '12',
#   'restaurant': "Applebee's"},
#  {'name': 'Classic Club House Grill',
#   'category': 'Sandwiches',
#   'calories': '1150',
#   'fat': '67',
#   'carbs': '77',
#   'restaurant': "Applebee's"},
#  {'name': 'Crunchy Onion Rings, Side',
#   'category': 'Sides',
#   'calories': '530',
#   'fat': '28',
#   'carbs': '63',
#   'restaurant': "Applebee's"},
#  {'name': 'French Onion Soup',
#   'category': 'Soups',
#   'calories': '260',
#   'fat': '14',
#   'carbs': '16',
#   'restaurant': "Applebee's"},
#  {'name': 'Frozen Lemonades',
#   'category': 'Drinks',
#   'calories': '255',
#   'fat': '0',
#   'carbs': '64',
#   'restaurant': "Applebee's"},
#  {'name': 'Grilled Shrimp ‘N Spinach Salad',
#   'category': 'Salads',
#   'calories': '260',
#   'fat': '15',
#   'carbs': '20',
#   'restaurant': "Applebee's"},
#  {'name': 'Grilled Steak Caesar, Half w/o dressing',
#   'category': 'Salads',
#   'calories': '230',
#   'fat': '10',
#   'carbs': '11',
#   'restaurant': "Applebee's"},
#  {'name': 'House Sirloin',
#   'category': 'Entrees',
#   'calories': '250',
#   'fat': '12',
#   'carbs': '0',
#   'restaurant': "Applebee's"},
#  {'name': 'Kids Grape Juice (6.75 oz)',
#   'category': "Kid's Meals",
#   'calories': '80',
#   'fat': '0',
#   'carbs': '20',
#   'restaurant': "Applebee's"},
#  {'name': 'Kids Mini Hamburger – 1',
#   'category': "Kid's Meals",
#   'calories': '390',
#   'fat': '27',
#   'carbs': '23',
#   'restaurant': "Applebee's"},
#  {'name': 'Kids Vanilla Sundae with Hershey’s Syrup',
#   'category': "Kid's Meals",
#   'calories': '330',
#   'fat': '14',
#   'carbs': '49',
#   'restaurant': "Applebee's"},
#  {'name': 'Oriental Chicken Salad',
#   'category': 'Salads',
#   'calories': '420',
#   'fat': '29',
#   'carbs': '25',
#   'restaurant': "Applebee's"},
#  {'name': 'Pecan-Crusted Chicken Salad, Half',
#   'category': 'Salads',
#   'calories': '820',
#   'fat': '48',
#   'carbs': '72',
#   'restaurant': "Applebee's"},
#  {'name': 'Queso Blanco',
#   'category': 'Appetizers',
#   'calories': '1330',
#   'fat': '82',
#   'carbs': '114',
#   'restaurant': "Applebee's"},
#  {'name': 'Santa Fe Chicken Salad, Regular w/o dressing',
#   'category': 'Salads',
#   'calories': '870',
#   'fat': '56',
#   'carbs': '52',
#   'restaurant': "Applebee's"},
#  {'name': 'Sizzling Skillet Fajitas - Combo',
#   'category': 'Entrees',
#   'calories': '1430',
#   'fat': '60',
#   'carbs': '150',
#   'restaurant': "Applebee's"},
#  {'name': 'Spinach & Artichoke Dip',
#   'category': 'Appetizers',
#   'calories': '1525',
#   'fat': '102',
#   'carbs': '124',
#   'restaurant': "Applebee's"},
#  {'name': 'Teriyaki Chicken Pasta',
#   'category': 'Entrees',
#   'calories': '450',
#   'fat': '8',
#   'carbs': '73',
#   'restaurant': "Applebee's"},
#  {'name': 'Trios Chicken Quesadilla Grande',
#   'category': 'Appetizers',
#   'calories': '650',
#   'fat': '47',
#   'carbs': '44',
#   'restaurant': "Applebee's"},
#  {'name': 'Trios Spinach Artichoke Dip',
#   'category': 'Appetizers',
#   'calories': '560',
#   'fat': '39',
#   'carbs': '41',
#   'restaurant': "Applebee's"},
#  {'name': 'Weight Watchers® Spicy Pineapple Glazed Shrimp & Spinach',
#   'category': 'Seafood',
#   'calories': '310',
#   'fat': '5',
#   'carbs': '48',
#   'restaurant': "Applebee's"},
#  {'name': 'Applebee’s House Salad',
#   'category': 'Salads',
#   'calories': '180',
#   'fat': '15',
#   'carbs': '12',
#   'restaurant': "Applebee's"},
#  {'name': 'Bacon Cheese Chicken Grill',
#   'category': 'Sandwiches',
#   'calories': '750',
#   'fat': '33',
#   'carbs': '50',
#   'restaurant': "Applebee's"},
#  {'name': 'Boneless Wings, Hot Buffalo',
#   'category': 'Appetizers',
#   'calories': '1170',
#   'fat': '69',
#   'carbs': '67',
#   'restaurant': "Applebee's"},
#  {'name': 'Bruschetta Chicken Salad, Half',
#   'category': 'Salads',
#   'calories': '740',
#   'fat': '44',
#   'carbs': '45',
#   'restaurant': "Applebee's"},
#  {'name': 'California Turkey Club',
#   'category': 'Sandwiches',
#   'calories': '970',
#   'fat': '55',
#   'carbs': '60',
#   'restaurant': "Applebee's"},
#  {'name': 'Chicken Fajita Rollup',
#   'category': 'Sandwiches',
#   'calories': '560',
#   'fat': '41',
#   'carbs': '45',
#   'restaurant': "Applebee's"},
#  {'name': 'Chicken Tortilla Soup',
#   'category': 'Soups',
#   'calories': '180',
#   'fat': '8',
#   'carbs': '18',
#   'restaurant': "Applebee's"},
#  {'name': 'Clam Chowder',
#   'category': 'Soups',
#   'calories': '290',
#   'fat': '20',
#   'carbs': '16',
#   'restaurant': "Applebee's"},
#  {'name': 'Crunchy Onion Rings',
#   'category': 'Appetizers',
#   'calories': '1290',
#   'fat': '56',
#   'carbs': '181',
#   'restaurant': "Applebee's"},
#  {'name': 'French Dip Sliders',
#   'category': 'Burgers',
#   'calories': '590',
#   'fat': '36',
#   'carbs': '50',
#   'restaurant': "Applebee's"},
#  {'name': 'Fries, Side',
#   'category': "Kid's Meals",
#   'calories': '390',
#   'fat': '18',
#   'carbs': '53',
#   'restaurant': "Applebee's"},
#  {'name': 'Grilled Dijon Chicken & Portobellos',
#   'category': 'Chicken',
#   'calories': '470',
#   'fat': '16',
#   'carbs': '30',
#   'restaurant': "Applebee's"},
#  {'name': 'Grilled Steak Caesar, Half',
#   'category': 'Salads',
#   'calories': '460',
#   'fat': '34',
#   'carbs': '13',
#   'restaurant': "Applebee's"},
#  {'name': 'House Sirloin',
#   'category': 'Entrees',
#   'calories': '310',
#   'fat': '13',
#   'carbs': '0',
#   'restaurant': "Applebee's"},
#  {'name': 'Kids Fried Shrimp',
#   'category': "Kid's Meals",
#   'calories': '230',
#   'fat': '14',
#   'carbs': '16',
#   'restaurant': "Applebee's"},
#  {'name': 'Kids Mini Cheeseburgers – 2',
#   'category': "Kid's Meals",
#   'calories': '740',
#   'fat': '46',
#   'carbs': '47',
#   'restaurant': "Applebee's"},
#  {'name': 'Kids Vanilla Sundae',
#   'category': "Kid's Meals",
#   'calories': '230',
#   'fat': '14',
#   'carbs': '24',
#   'restaurant': "Applebee's"},
#  {'name': 'Oriental Chicken Rollup',
#   'category': 'Sandwiches',
#   'calories': '1160',
#   'fat': '60',
#   'carbs': '121',
#   'restaurant': "Applebee's"},
#  {'name': 'Oriental Grilled Chicken Salad, Regular w/o dressing',
#   'category': 'Salads',
#   'calories': '590',
#   'fat': '19',
#   'carbs': '58',
#   'restaurant': "Applebee's"},
#  {'name': 'Quesadilla Burger',
#   'category': 'Burgers',
#   'calories': '1240',
#   'fat': '103',
#   'carbs': '44',
#   'restaurant': "Applebee's"},
#  {'name': 'Santa Fe Chicken Salad, Regular',
#   'category': 'Salads',
#   'calories': '1240',
#   'fat': '93',
#   'carbs': '58',
#   'restaurant': "Applebee's"},
#  {'name': 'Sizzling Skillet Fajitas - Chicken',
#   'category': 'Entrees',
#   'calories': '1370',
#   'fat': '52',
#   'carbs': '149',
#   'restaurant': "Applebee's"},
#  {'name': 'Spicy Chili Cheese Nachos',
#   'category': 'Appetizers',
#   'calories': '1610',
#   'fat': '103',
#   'carbs': '125',
#   'restaurant': "Applebee's"},
#  {'name': 'Stuffed Meatball Sandwich',
#   'category': 'Sandwiches',
#   'calories': '1090',
#   'fat': '58',
#   'carbs': '90',
#   'restaurant': "Applebee's"},
#  {'name': 'Trios Cheeseburger Sliders',
#   'category': 'Appetizers',
#   'calories': '880',
#   'fat': '59',
#   'carbs': '55',
#   'restaurant': "Applebee's"},
#  {'name': 'Trios Spicy Queso Blanco',
#   'category': 'Appetizers',
#   'calories': '520',
#   'fat': '33',
#   'carbs': '40',
#   'restaurant': "Applebee's"},
#  {'name': 'Weight Watchers® Paradise Chicken Salad',
#   'category': 'Salads',
#   'calories': '340',
#   'fat': '4',
#   'carbs': '6',
#   'restaurant': "Applebee's"},
#  {'name': 'Appetizer Sampler',
#   'category': 'Appetizers',
#   'calories': '2375',
#   'fat': '162',
#   'carbs': '169',
#   'restaurant': "Applebee's"},
#  {'name': 'Applebee’s Riblets Basket',
#   'category': 'Ribs',
#   'calories': '1115',
#   'fat': '55',
#   'carbs': '92',
#   'restaurant': "Applebee's"},
#  {'name': 'Black Bean Soup',
#   'category': 'Soups',
#   'calories': '190',
#   'fat': '9',
#   'carbs': '21',
#   'restaurant': "Applebee's"},
#  {'name': 'Breadstick',
#   'category': 'Sides',
#   'calories': '290',
#   'fat': '19',
#   'carbs': '22',
#   'restaurant': "Applebee's"},
#  {'name': 'Cajun Shrimp Pasta',
#   'category': 'Entrees',
#   'calories': '1170',
#   'fat': '69',
#   'carbs': '95',
#   'restaurant': "Applebee's"},
#  {'name': 'Cheeseburger Sliders with Applewood Smoked Bacon',
#   'category': 'Burgers',
#   'calories': '1330',
#   'fat': '87',
#   'carbs': '83',
#   'restaurant': "Applebee's"},
#  {'name': 'Chicken Noodle Soup',
#   'category': 'Soups',
#   'calories': '110',
#   'fat': '3',
#   'carbs': '11',
#   'restaurant': "Applebee's"},
#  {'name': 'Chili Cheese Nachos',
#   'category': 'Appetizers',
#   'calories': '1680',
#   'fat': '107',
#   'carbs': '134',
#   'restaurant': "Applebee's"},
#  {'name': 'Classic Wings, Southern BBQ',
#   'category': 'Appetizers',
#   'calories': '660',
#   'fat': '35',
#   'carbs': '25',
#   'restaurant': "Applebee's"},
#  {'name': 'Double-Glazed Baby Back Ribs - Half Rack',
#   'category': 'Ribs',
#   'calories': '935',
#   'fat': '49',
#   'carbs': '88',
#   'restaurant': "Applebee's"},
#  {'name': 'Fried Chicken Salad, Half w/o dressing',
#   'category': 'Salads',
#   'calories': '310',
#   'fat': '23',
#   'carbs': '12',
#   'restaurant': "Applebee's"},
#  {'name': 'Grilled Chicken Caesar, Half w/o dressing',
#   'category': 'Salads',
#   'calories': '180',
#   'fat': '5',
#   'carbs': '10',
#   'restaurant': "Applebee's"},
#  {'name': 'Grilled Shrimp ‘N Spinach Salad, Regular w/o dressing',
#   'category': 'Salads',
#   'calories': '680',
#   'fat': '51',
#   'carbs': '20',
#   'restaurant': "Applebee's"},
#  {'name': 'Hand-Battered Fish & Chips',
#   'category': 'Seafood',
#   'calories': '1570',
#   'fat': '106',
#   'carbs': '108',
#   'restaurant': "Applebee's"},
#  {'name': 'Kids Celery side with Dressing',
#   'category': "Kid's Meals",
#   'calories': '220',
#   'fat': '22',
#   'carbs': '5',
#   'restaurant': "Applebee's"},
#  {'name': 'Kids Hot Dog',
#   'category': "Kid's Meals",
#   'calories': '330',
#   'fat': '18',
#   'carbs': '31',
#   'restaurant': "Applebee's"},
#  {'name': 'Kids OREO® Cookie Sundae',
#   'category': "Kid's Meals",
#   'calories': '360',
#   'fat': '19',
#   'carbs': '43',
#   'restaurant': "Applebee's"},
#  {'name': 'Margherita Chicken',
#   'category': 'Chicken',
#   'calories': '800',
#   'fat': '30',
#   'carbs': '67',
#   'restaurant': "Applebee's"},
#  {'name': 'Oriental Chicken Salad, Regular w/o dressing',
#   'category': 'Salads',
#   'calories': '680',
#   'fat': '41',
#   'carbs': '50',
#   'restaurant': "Applebee's"},
#  {'name': 'Philly Burger',
#   'category': 'Burgers',
#   'calories': '1130',
#   'fat': '67',
#   'carbs': '70',
#   'restaurant': "Applebee's"},
#  {'name': 'Riblet and Chicken Tenders Basket',
#   'category': 'Chicken',
#   'calories': '1295',
#   'fat': '73',
#   'carbs': '103',
#   'restaurant': "Applebee's"},
#  {'name': 'Signature Sirloin with Garlic Herb Shrimp',
#   'category': 'Entrees',
#   'calories': '500',
#   'fat': '21',
#   'carbs': '31',
#   'restaurant': "Applebee's"},
#  {'name': 'Sizzling Steak & Cheese',
#   'category': 'Entrees',
#   'calories': '1050',
#   'fat': '65',
#   'carbs': '49',
#   'restaurant': "Applebee's"},
#  {'name': 'Steak & Honey BBQ Chicken Combo',
#   'category': 'Entrees',
#   'calories': '600',
#   'fat': '15',
#   'carbs': '37',
#   'restaurant': "Applebee's"},
#  {'name': 'Toasted Garlic Bread Basket',
#   'category': 'Sides',
#   'calories': '1120',
#   'fat': '78',
#   'carbs': '89',
#   'restaurant': "Applebee's"},
#  {'name': 'Trios Boneless Wings, Honey BBQ',
#   'category': 'Appetizers',
#   'calories': '620',
#   'fat': '28',
#   'carbs': '58',
#   'restaurant': "Applebee's"},
#  {'name': 'Trios Classic Wings, Southern BBQ',
#   'category': 'Appetizers',
#   'calories': '330',
#   'fat': '17',
#   'carbs': '13',
#   'restaurant': "Applebee's"},
#  {'name': 'Triple Chocolate Meltdown®',
#   'category': 'Desserts',
#   'calories': '820',
#   'fat': '48',
#   'carbs': '97',
#   'restaurant': "Applebee's"},
#  {'name': 'Wonton Tacos',
#   'category': 'Appetizers',
#   'calories': '495',
#   'fat': '23',
#   'carbs': '45',
#   'restaurant': "Applebee's"},
#  {'name': 'Apple Walnut Chicken Salad, Half',
#   'category': 'Salads',
#   'calories': '630',
#   'fat': '43',
#   'carbs': '33',
#   'restaurant': "Applebee's"},
#  {'name': 'Applebee’s Riblets Platter',
#   'category': 'Ribs',
#   'calories': '1705',
#   'fat': '86',
#   'carbs': '134',
#   'restaurant': "Applebee's"},
#  {'name': 'Blackened Tilapia Sandwich',
#   'category': 'Sandwiches',
#   'calories': '740',
#   'fat': '42',
#   'carbs': '54',
#   'restaurant': "Applebee's"},
#  {'name': 'Broccoli Cheddar Soup',
#   'category': 'Soups',
#   'calories': '340',
#   'fat': '26',
#   'carbs': '19',
#   'restaurant': "Applebee's"},
#  {'name': 'California Shrimp Salad, Half',
#   'category': 'Salads',
#   'calories': '500',
#   'fat': '42',
#   'carbs': '16',
#   'restaurant': "Applebee's"},
#  {'name': 'Cheesy Corn',
#   'category': 'Sides',
#   'calories': '350',
#   'fat': '20',
#   'carbs': '28',
#   'restaurant': "Applebee's"},
#  {'name': 'Chicken Parmesan Stack',
#   'category': 'Chicken',
#   'calories': '1690',
#   'fat': '95',
#   'carbs': '130',
#   'restaurant': "Applebee's"},
#  {'name': 'Chips and Spicy Chipotle Lime Salsa',
#   'category': 'Appetizers',
#   'calories': '960',
#   'fat': '53',
#   'carbs': '106',
#   'restaurant': "Applebee's"},
#  {'name': 'Classic Wings, Sweet & spicy sauce',
#   'category': 'Appetizers',
#   'calories': '690',
#   'fat': '35',
#   'carbs': '32',
#   'restaurant': "Applebee's"},
#  {'name': 'Fiesta Lime Chicken®',
#   'category': 'Chicken',
#   'calories': '1160',
#   'fat': '67',
#   'carbs': '94',
#   'restaurant': "Applebee's"},
#  {'name': 'Fried Chicken Salad, Regular',
#   'category': 'Salads',
#   'calories': '980',
#   'fat': '79',
#   'carbs': '50',
#   'restaurant': "Applebee's"},
#  {'name': 'Grilled Chicken Caesar, Regular',
#   'category': 'Salads',
#   'calories': '820',
#   'fat': '57',
#   'carbs': '25',
#   'restaurant': "Applebee's"},
#  {'name': 'Hand-Battered Fish Sandwich',
#   'category': 'Sandwiches',
#   'calories': '860',
#   'fat': '58',
#   'carbs': '63',
#   'restaurant': "Applebee's"},
#  {'name': 'Kids Cheese Pizza',
#   'category': "Kid's Meals",
#   'calories': '550',
#   'fat': '31',
#   'carbs': '44',
#   'restaurant': "Applebee's"},
#  {'name': 'Kids Hot Fudge Sundae',
#   'category': "Kid's Meals",
#   'calories': '350',
#   'fat': '18',
#   'carbs': '45',
#   'restaurant': "Applebee's"},
#  {'name': 'Kids Pasta with Marinara Sauce',
#   'category': "Kid's Meals",
#   'calories': '360',
#   'fat': '7',
#   'carbs': '60',
#   'restaurant': "Applebee's"},
#  {'name': 'Mozzarella Sticks',
#   'category': 'Appetizers',
#   'calories': '940',
#   'fat': '48',
#   'carbs': '84',
#   'restaurant': "Applebee's"},
#  {'name': 'Oriental Grilled Chicken Salad',
#   'category': 'Salads',
#   'calories': '430',
#   'fat': '21',
#   'carbs': '36',
#   'restaurant': "Applebee's"},
#  {'name': 'Pork Wonton Tacos',
#   'category': 'Appetizers',
#   'calories': '820',
#   'fat': '41',
#   'carbs': '68',
#   'restaurant': "Applebee's"},
#  {'name': 'Riblet and Chicken Tenders Platter',
#   'category': 'Chicken',
#   'calories': '1800',
#   'fat': '101',
#   'carbs': '136',
#   'restaurant': "Applebee's"},
#  {'name': 'Sizzling Apple Pie',
#   'category': 'Desserts',
#   'calories': '900',
#   'fat': '33',
#   'carbs': '145',
#   'restaurant': "Applebee's"},
#  {'name': 'Slow Simmered Tender Beef Sandwich',
#   'category': 'Sandwiches',
#   'calories': '980',
#   'fat': '50',
#   'carbs': '101',
#   'restaurant': "Applebee's"},
#  {'name': 'Steak & Riblets Combo',
#   'category': 'Entrees',
#   'calories': '985',
#   'fat': '49',
#   'carbs': '39',
#   'restaurant': "Applebee's"},
#  {'name': 'Tomato Basil Soup',
#   'category': 'Soups',
#   'calories': '220',
#   'fat': '13',
#   'carbs': '22',
#   'restaurant': "Applebee's"},
#  {'name': 'Trios Boneless Wings, Hot Buffalo',
#   'category': 'Appetizers',
#   'calories': '590',
#   'fat': '35',
#   'carbs': '33',
#   'restaurant': "Applebee's"},
#  {'name': 'Trios Classic Wings, Sweet & spicy sauce',
#   'category': 'Appetizers',
#   'calories': '350',
#   'fat': '18',
#   'carbs': '16',
#   'restaurant': "Applebee's"},
#  {'name': 'Veggie Burger',
#   'category': 'Burgers',
#   'calories': '550',
#   'fat': '22',
#   'carbs': '60',
#   'restaurant': "Applebee's"},
#  {'name': 'Zesty Ranch Chicken Sandwich',
#   'category': 'Sandwiches',
#   'calories': '1150',
#   'fat': '73',
#   'carbs': '76',
#   'restaurant': "Applebee's"},
#  {'name': 'Applebee’s Limeades',
#   'category': 'Drinks',
#   'calories': '130',
#   'fat': '0',
#   'carbs': '59',
#   'restaurant': "Applebee's"},
#  {'name': 'Baked Potato Soup',
#   'category': 'Soups',
#   'calories': '420',
#   'fat': '32',
#   'carbs': '27',
#   'restaurant': "Applebee's"},
#  {'name': 'Boneless Wings, Sweet & spicy sauce',
#   'category': 'Appetizers',
#   'calories': '1150',
#   'fat': '55',
#   'carbs': '90',
#   'restaurant': "Applebee's"},
#  {'name': 'Bruschetta Chicken Salad, Regular',
#   'category': 'Salads',
#   'calories': '1110',
#   'fat': '66',
#   'carbs': '67',
#   'restaurant': "Applebee's"},
#  {'name': 'Cheeseburger',
#   'category': 'Burgers',
#   'calories': '940',
#   'fat': '58',
#   'carbs': '52',
#   'restaurant': "Applebee's"},
#  {'name': 'Chicken Fried Chicken',
#   'category': 'Chicken',
#   'calories': '1230',
#   'fat': '59',
#   'carbs': '112',
#   'restaurant': "Applebee's"},
#  {'name': 'Chili',
#   'category': 'Soups',
#   'calories': '310',
#   'fat': '26',
#   'carbs': '10',
#   'restaurant': "Applebee's"},
#  {'name': 'Classic Wings, Classic Buffalo',
#   'category': 'Appetizers',
#   'calories': '710',
#   'fat': '49',
#   'carbs': '8',
#   'restaurant': "Applebee's"},
#  {'name': 'Decadent Shakes',
#   'category': 'Shakes',
#   'calories': '915',
#   'fat': '46',
#   'carbs': '109',
#   'restaurant': "Applebee's"},
#  {'name': 'Fresh Fruit, Side',
#   'category': 'Sides',
#   'calories': '90',
#   'fat': '0',
#   'carbs': '24',
#   'restaurant': "Applebee's"},
#  {'name': 'Garlic Herb Salmon',
#   'category': 'Seafood',
#   'calories': '690',
#   'fat': '29',
#   'carbs': '61',
#   'restaurant': "Applebee's"},
#  {'name': 'Grilled Shrimp ‘N Spinach Salad, Half',
#   'category': 'Salads',
#   'calories': '620',
#   'fat': '44',
#   'carbs': '33',
#   'restaurant': "Applebee's"},
#  {'name': 'Grilled Steak Caesar, Regular',
#   'category': 'Salads',
#   'calories': '910',
#   'fat': '68',
#   'carbs': '25',
#   'restaurant': "Applebee's"},
#  {'name': 'Kids 4oz Sirloin Steak',
#   'category': "Kid's Meals",
#   'calories': '140',
#   'fat': '7',
#   'carbs': '0',
#   'restaurant': "Applebee's"},
#  {'name': 'Kids Grilled Cheese (Hawaiian bread)',
#   'category': "Kid's Meals",
#   'calories': '610',
#   'fat': '36',
#   'carbs': '51',
#   'restaurant': "Applebee's"},
#  {'name': 'Kids Mini Hamburger – 2',
#   'category': "Kid's Meals",
#   'calories': '660',
#   'fat': '40',
#   'carbs': '46',
#   'restaurant': "Applebee's"},
#  {'name': 'Loaded Baked Potato',
#   'category': 'Sides',
#   'calories': '500',
#   'fat': '35',
#   'carbs': '42',
#   'restaurant': "Applebee's"},
#  {'name': 'Oriental Chicken Salad, Half',
#   'category': 'Salads',
#   'calories': '670',
#   'fat': '49',
#   'carbs': '42',
#   'restaurant': "Applebee's"},
#  {'name': 'Pecan-Crusted Chicken Salad, Half w/o dressing',
#   'category': 'Salads',
#   'calories': '580',
#   'fat': '31',
#   'carbs': '53',
#   'restaurant': "Applebee's"},
#  {'name': 'Queso Blanco with chili',
#   'category': 'Appetizers',
#   'calories': '1440',
#   'fat': '89',
#   'carbs': '118',
#   'restaurant': "Applebee's"},
#  {'name': 'Seasonal Vegetables, Side',
#   'category': 'Sides',
#   'calories': '42',
#   'fat': '0',
#   'carbs': '8',
#   'restaurant': "Applebee's"},
#  {'name': 'Sizzling Skillet Fajitas - Shrimp',
#   'category': 'Entrees',
#   'calories': '1400',
#   'fat': '65',
#   'carbs': '151',
#   'restaurant': "Applebee's"},
#  {'name': 'Spinach Salad',
#   'category': 'Salads',
#   'calories': '230',
#   'fat': '15',
#   'carbs': '19',
#   'restaurant': "Applebee's"},
#  {'name': 'Teriyaki Shrimp Pasta',
#   'category': 'Entrees',
#   'calories': '440',
#   'fat': '8',
#   'carbs': '74',
#   'restaurant': "Applebee's"},
#  {'name': 'Topper - Sautéed Garlic Mushrooms',
#   'category': 'Sides',
#   'calories': '130',
#   'fat': '12',
#   'carbs': '4',
#   'restaurant': "Applebee's"},
#  {'name': 'Trios Classic Wings, Classic Buffalo',
#   'category': 'Appetizers',
#   'calories': '360',
#   'fat': '24',
#   'carbs': '4',
#   'restaurant': "Applebee's"},
#  {'name': 'Trios Steak Quesadilla Towers',
#   'category': 'Appetizers',
#   'calories': '560',
#   'fat': '38',
#   'carbs': '37',
#   'restaurant': "Applebee's"},
#  {'name': 'Weight Watchers® Steak & Potato Salad',
#   'category': 'Salads',
#   'calories': '380',
#   'fat': '12',
#   'carbs': '32',
#   'restaurant': "Applebee's"},
#  {'name': 'Add Grilled Shrimp',
#   'category': 'Sides',
#   'calories': '230',
#   'fat': '17',
#   'carbs': '2',
#   'restaurant': "Applebee's"},
#  {'name': 'Applebee’s Reuben',
#   'category': 'Sandwiches',
#   'calories': '630',
#   'fat': '47',
#   'carbs': '25',
#   'restaurant': "Applebee's"},
#  {'name': 'BBQ Pulled Pork Sliders',
#   'category': 'Burgers',
#   'calories': '1030',
#   'fat': '48',
#   'carbs': '90',
#   'restaurant': "Applebee's"},
#  {'name': 'Bourbon Street Steak',
#   'category': 'Entrees',
#   'calories': '760',
#   'fat': '44',
#   'carbs': '35',
#   'restaurant': "Applebee's"},
#  {'name': 'Caesar Salad',
#   'category': 'Salads',
#   'calories': '220',
#   'fat': '19',
#   'carbs': '8',
#   'restaurant': "Applebee's"},
#  {'name': 'Cheeseburger Sliders add bacon',
#   'category': 'Burgers',
#   'calories': '1330',
#   'fat': '87',
#   'carbs': '83',
#   'restaurant': "Applebee's"},
#  {'name': 'Chicken Noodle Soup',
#   'category': 'Soups',
#   'calories': '160',
#   'fat': '4',
#   'carbs': '17',
#   'restaurant': "Applebee's"},
#  {'name': 'Chili Cheese Fries, Side',
#   'category': 'French Fries',
#   'calories': '550',
#   'fat': '33',
#   'carbs': '59',
#   'restaurant': "Applebee's"},
#  {'name': 'Classic Wings, Hot Buffalo',
#   'category': 'Appetizers',
#   'calories': '720',
#   'fat': '49',
#   'carbs': '9',
#   'restaurant': "Applebee's"},
#  {'name': 'Double-Glazed Baby Back Ribs',
#   'category': 'Ribs',
#   'calories': '1345',
#   'fat': '72',
#   'carbs': '95',
#   'restaurant': "Applebee's"},
#  {'name': 'Fried Chicken Salad, Half',
#   'category': 'Salads',
#   'calories': '530',
#   'fat': '42',
#   'carbs': '26',
#   'restaurant': "Applebee's"},
#  {'name': 'Grilled Chicken Caesar, Half',
#   'category': 'Salads',
#   'calories': '410',
#   'fat': '29',
#   'carbs': '12',
#   'restaurant': "Applebee's"},
#  {'name': 'Grilled Shrimp ‘N Spinach Salad, Regular',
#   'category': 'Salads',
#   'calories': '1010',
#   'fat': '69',
#   'carbs': '63',
#   'restaurant': "Applebee's"},
#  {'name': 'Hamburger',
#   'category': 'Burgers',
#   'calories': '790',
#   'fat': '46',
#   'carbs': '50',
#   'restaurant': "Applebee's"},
#  {'name': 'Kids Applesauce side',
#   'category': "Kid's Meals",
#   'calories': '50',
#   'fat': '0',
#   'carbs': '27',
#   'restaurant': "Applebee's"},
#  {'name': 'Kids Grilled Chicken Sandwich',
#   'category': "Kid's Meals",
#   'calories': '230',
#   'fat': '5',
#   'carbs': '23',
#   'restaurant': "Applebee's"},
#  {'name': 'Kids OREO® Cookie Milkshake',
#   'category': "Kid's Meals",
#   'calories': '780',
#   'fat': '41',
#   'carbs': '97',
#   'restaurant': "Applebee's"},
#  {'name': 'Maple Butter Blondie',
#   'category': 'Desserts',
#   'calories': '1100',
#   'fat': '63',
#   'carbs': '115',
#   'restaurant': "Applebee's"},
#  {'name': 'Oriental Chicken Salad, Regular',
#   'category': 'Salads',
#   'calories': '1340',
#   'fat': '98',
#   'carbs': '85',
#   'restaurant': "Applebee's"},
#  {'name': 'Pecan-Crusted Chicken Salad, Regular w/o dressing',
#   'category': 'Salads',
#   'calories': '880',
#   'fat': '46',
#   'carbs': '76',
#   'restaurant': "Applebee's"},
#  {'name': 'Ribeye',
#   'category': 'Entrees',
#   'calories': '670',
#   'fat': '47',
#   'carbs': '3',
#   'restaurant': "Applebee's"},
#  {'name': 'Shrimp Fettuccine Alfredo',
#   'category': 'Entrees',
#   'calories': '143',
#   'fat': '81',
#   'carbs': '113',
#   'restaurant': "Applebee's"},
#  {'name': 'Sizzling Smokehouse Chicken Stack',
#   'category': 'Entrees',
#   'calories': '1170',
#   'fat': '59',
#   'carbs': '78',
#   'restaurant': "Applebee's"},
#  {'name': 'Steak & Grilled Shrimp Combo',
#   'category': 'Entrees',
#   'calories': '540',
#   'fat': '36',
#   'carbs': '2',
#   'restaurant': "Applebee's"},
#  {'name': 'Three-Cheese Chicken Penne',
#   'category': 'Entrees',
#   'calories': '1460',
#   'fat': '75',
#   'carbs': '127',
#   'restaurant': "Applebee's"},
#  {'name': 'Trios Boneless Wings, Classic Buffalo',
#   'category': 'Appetizers',
#   'calories': '580',
#   'fat': '35',
#   'carbs': '33',
#   'restaurant': "Applebee's"},
#  {'name': 'Trios Classic Wings, Hot Buffalo',
#   'category': 'Appetizers',
#   'calories': '360',
#   'fat': '25',
#   'carbs': '4',
#   'restaurant': "Applebee's"},
#  {'name': 'Trios Wings Ranch Dipping Sauce',
#   'category': 'Appetizers',
#   'calories': '200',
#   'fat': '21',
#   'carbs': '1',
#   'restaurant': "Applebee's"},
#  {'name': 'Wings Ranch Dipping Sauce',
#   'category': 'Appetizers',
#   'calories': '200',
#   'fat': '21',
#   'carbs': '1',
#   'restaurant': "Applebee's"},
#  {'name': 'Add Fried Shrimp',
#   'category': 'Sides',
#   'calories': '390',
#   'fat': '21',
#   'carbs': '35',
#   'restaurant': "Applebee's"},
#  {'name': 'Applebee’s Reuben',
#   'category': 'Sandwiches',
#   'calories': '1140',
#   'fat': '81',
#   'carbs': '49',
#   'restaurant': "Applebee's"},
#  {'name': 'Baked Potato Soup',
#   'category': 'Soups',
#   'calories': '360',
#   'fat': '28',
#   'carbs': '20',
#   'restaurant': "Applebee's"},
#  {'name': 'Bourbon Street Chicken & Shrimp',
#   'category': 'Entrees',
#   'calories': '750',
#   'fat': '45',
#   'carbs': '31',
#   'restaurant': "Applebee's"},
#  {'name': 'Bruschetta Chicken Salad, Regular w/o dressing',
#   'category': 'Salads',
#   'calories': '790',
#   'fat': '36',
#   'carbs': '56',
#   'restaurant': "Applebee's"},
#  {'name': 'Cheeseburger Sliders',
#   'category': 'Burgers',
#   'calories': '1270',
#   'fat': '82',
#   'carbs': '82',
#   'restaurant': "Applebee's"},
#  {'name': 'Chicken Fried Steak (includes mashed potato, gravy & vegetable)',
#   'category': 'Entrees',
#   'calories': '1260',
#   'fat': '61',
#   'carbs': '118',
#   'restaurant': "Applebee's"},
#  {'name': 'Chili',
#   'category': 'Soups',
#   'calories': '370',
#   'fat': '28',
#   'carbs': '16',
#   'restaurant': "Applebee's"},
#  {'name': 'Classic Wings, Honey BBQ',
#   'category': 'Appetizers',
#   'calories': '790',
#   'fat': '35',
#   'carbs': '59',
#   'restaurant': "Applebee's"},
#  {'name': 'Double Crunch Shrimp',
#   'category': 'Seafood',
#   'calories': '1280',
#   'fat': '69',
#   'carbs': '133',
#   'restaurant': "Applebee's"},
#  {'name': 'Fried Chicken Salad',
#   'category': 'Salads',
#   'calories': '380',
#   'fat': '27',
#   'carbs': '20',
#   'restaurant': "Applebee's"},
#  {'name': 'Garlic Mashed Potatoes',
#   'category': 'Sides',
#   'calories': '330',
#   'fat': '18',
#   'carbs': '38',
#   'restaurant': "Applebee's"},
#  {'name': 'Grilled Shrimp ‘N Spinach Salad, Half w/o dressing',
#   'category': 'Salads',
#   'calories': '460',
#   'fat': '35',
#   'carbs': '12',
#   'restaurant': "Applebee's"},
#  {'name': 'Grilled Steak Caesar, Regular w/o dressing',
#   'category': 'Salads',
#   'calories': '460',
#   'fat': '21',
#   'carbs': '21',
#   'restaurant': "Applebee's"},
#  {'name': 'Kids Apple Juice (6.75 oz)',
#   'category': "Kid's Meals",
#   'calories': '70',
#   'fat': '0',
#   'carbs': '17',
#   'restaurant': "Applebee's"},
#  {'name': 'Kids Grilled Cheese (sourdough bread)',
#   'category': "Kid's Meals",
#   'calories': '630',
#   'fat': '36',
#   'carbs': '54',
#   'restaurant': "Applebee's"},
#  {'name': 'Kids Orange-Tangerine Juice (6.75 oz)',
#   'category': "Kid's Meals",
#   'calories': '70',
#   'fat': '0',
#   'carbs': '17',
#   'restaurant': "Applebee's"},
#  {'name': 'Loaded Mashed Potatoes',
#   'category': 'Sides',
#   'calories': '550',
#   'fat': '42',
#   'carbs': '41',
#   'restaurant': "Applebee's"},
#  {'name': 'Oriental Chicken Salad, Half w/o dressing',
#   'category': 'Salads',
#   'calories': '340',
#   'fat': '20',
#   'carbs': '25',
#   'restaurant': "Applebee's"},
#  {'name': 'Pecan-Crusted Chicken Salad, Regular',
#   'category': 'Salads',
#   'calories': '1350',
#   'fat': '80',
#   'carbs': '114',
#   'restaurant': "Applebee's"},
#  {'name': 'Red Beans & Rice',
#   'category': 'Sides',
#   'calories': '290',
#   'fat': '6',
#   'carbs': '48',
#   'restaurant': "Applebee's"},
#  {'name': 'Shrimp ‘N Parmesan Sirloin',
#   'category': 'Entrees',
#   'calories': '660',
#   'fat': '42',
#   'carbs': '4',
#   'restaurant': "Applebee's"},
#  {'name': 'Sizzling Skillet Fajitas - Steak',
#   'category': 'Entrees',
#   'calories': '1410',
#   'fat': '55',
#   'carbs': '152',
#   'restaurant': "Applebee's"},
#  {'name': 'Steak & Fried Shrimp Combo',
#   'category': 'Entrees',
#   'calories': '650',
#   'fat': '34',
#   'carbs': '37',
#   'restaurant': "Applebee's"},
#  {'name': 'Three-Cheese Chicken Penne',
#   'category': 'Entrees',
#   'calories': '940',
#   'fat': '49',
#   'carbs': '77',
#   'restaurant': "Applebee's"},
#  {'name': 'Topper - Shrimp ‘N Parmesan',
#   'category': 'Sides',
#   'calories': '230',
#   'fat': '15',
#   'carbs': '4',
#   'restaurant': "Applebee's"},
#  {'name': 'Trios Classic Wings, Honey BBQ',
#   'category': 'Appetizers',
#   'calories': '400',
#   'fat': '17',
#   'carbs': '29',
#   'restaurant': "Applebee's"},
#  {'name': 'Trios Wings Bleu Cheese Dipping Sauce',
#   'category': 'Appetizers',
#   'calories': '240',
#   'fat': '26',
#   'carbs': '1',
#   'restaurant': "Applebee's"},
#  {'name': 'Wings Bleu Cheese Dipping Sauce',
#   'category': 'Appetizers',
#   'calories': '240',
#   'fat': '26',
#   'carbs': '1',
#   'restaurant': "Applebee's"},
#  {'name': 'Apple Walnut Chicken Salad, Half w/o dressing',
#   'category': 'Salads',
#   'calories': '350',
#   'fat': '20',
#   'carbs': '15',
#   'restaurant': "Applebee's"},
#  {'name': 'Asiago Peppercorn Steak',
#   'category': 'Entrees',
#   'calories': '380',
#   'fat': '14',
#   'carbs': '25',
#   'restaurant': "Applebee's"},
# ...
#   'category': 'Shakes',
#   'calories': '400',
#   'fat': '7',
#   'carbs': '75',
#   'restaurant': 'Burger King'},
#  {'name': 'BK Toppers™ Deluxe Cheeseburger',
#   'category': 'Burgers',
#   'calories': '420',
#   'fat': '26',
#   'carbs': '30',
#   'restaurant': 'Burger King'},
#  {'name': 'Whopper® Sandwich w/o Mayo',
#   'category': 'Sandwiches',
#   'calories': '510',
#   'fat': '23',
#   'carbs': '51',
#   'restaurant': 'Burger King'},
#  {'name': 'Triple Whopper® Sandwich With Cheese w/o Mayo',
#   'category': 'Sandwiches',
#   'calories': '1070',
#   'fat': '64',
#   'carbs': '53',
#   'restaurant': 'Burger King'},
#  {'name': 'Cheeseburger',
#   'category': 'Burgers',
#   'calories': '300',
#   'fat': '14',
#   'carbs': '28',
#   'restaurant': 'Burger King'},
#  {'name': 'Tendergrill® Chicken Sandwich',
#   'category': 'Sandwiches',
#   'calories': '470',
#   'fat': '18',
#   'carbs': '40',
#   'restaurant': 'Burger King'},
#  {'name': "Spicy Chick'n Crisp® Sandwich w/o Mayo",
#   'category': 'Sandwiches',
#   'calories': '300',
#   'fat': '12',
#   'carbs': '35',
#   'restaurant': 'Burger King'},
#  {'name': 'BK® Chicken Fries (12 pc)',
#   'category': 'Sides',
#   'calories': '500',
#   'fat': '29',
#   'carbs': '32',
#   'restaurant': 'Burger King'},
#  {'name': 'French Fries - large (Salted)',
#   'category': 'French Fries',
#   'calories': '540',
#   'fat': '27',
#   'carbs': '69',
#   'restaurant': 'Burger King'},
#  {'name': "Ken's® Honey Mustard Dressing (2 oz)",
#   'category': 'Salads',
#   'calories': '270',
#   'fat': '23',
#   'carbs': '15',
#   'restaurant': 'Burger King'},
#  {'name': 'BK™ Ultimate Breakfast Platter',
#   'category': 'Breakfast',
#   'calories': '1310',
#   'fat': '72',
#   'carbs': '134',
#   'restaurant': 'Burger King'},
#  {'name': "Double Croissan'wich™ w/ Bacon, Egg, & Cheese",
#   'category': 'Breakfast',
#   'calories': '440',
#   'fat': '25',
#   'carbs': '27',
#   'restaurant': 'Burger King'},
#  {'name': 'Pancake Platter w/ Sausage & 1 oz Breakfast Syrup',
#   'category': 'Breakfast',
#   'calories': '670',
#   'fat': '34',
#   'carbs': '78',
#   'restaurant': 'Burger King'},
#  {'name': 'Cini‐minis (4 minis)',
#   'category': 'Breakfast',
#   'calories': '400',
#   'fat': '18',
#   'carbs': '52',
#   'restaurant': 'Burger King'},
#  {'name': 'Biscuit‐ w/ Breakfast Steak (Country Fried Steak)',
#   'category': 'Breakfast',
#   'calories': '650',
#   'fat': '38',
#   'carbs': '50',
#   'restaurant': 'Burger King'},
#  {'name': 'Chocolate Fudge Sundae',
#   'category': 'Desserts',
#   'calories': '280',
#   'fat': '7',
#   'carbs': '50',
#   'restaurant': 'Burger King'},
#  {'name': 'Vanilla Milk Shake',
#   'category': 'Shakes',
#   'calories': '660',
#   'fat': '17',
#   'carbs': '114',
#   'restaurant': 'Burger King'},
#  {'name': 'BK Toppers™ Western BBQ Cheeseburger',
#   'category': 'Burgers',
#   'calories': '400',
#   'fat': '23',
#   'carbs': '39',
#   'restaurant': 'Burger King'},
#  {'name': 'Whopper® Sandwich with Cheese',
#   'category': 'Sandwiches',
#   'calories': '760',
#   'fat': '47',
#   'carbs': '53',
#   'restaurant': 'Burger King'},
#  {'name': 'Texas Whopper® Sandwich',
#   'category': 'Sandwiches',
#   'calories': '800',
#   'fat': '51',
#   'carbs': '50',
#   'restaurant': 'Burger King'},
#  {'name': 'Double Hamburger',
#   'category': 'Burgers',
#   'calories': '360',
#   'fat': '18',
#   'carbs': '28',
#   'restaurant': 'Burger King'},
#  {'name': 'Tendergrill® Chicken Sandwich w/o Mayo',
#   'category': 'Sandwiches',
#   'calories': '360',
#   'fat': '7',
#   'carbs': '40',
#   'restaurant': 'Burger King'},
#  {'name': 'Chicken Tenders® (4 pc)',
#   'category': 'Chicken',
#   'calories': '190',
#   'fat': '11',
#   'carbs': '10',
#   'restaurant': 'Burger King'},
#  {'name': 'Country Pork Sandwich',
#   'category': 'Sandwiches',
#   'calories': '810',
#   'fat': '42',
#   'carbs': '78',
#   'restaurant': 'Burger King'},
#  {'name': 'Mozzarella Sticks (4 pc)',
#   'category': 'Sides',
#   'calories': '280',
#   'fat': '15',
#   'carbs': '24',
#   'restaurant': 'Burger King'},
#  {'name': 'Garlic Parmesan Croutons',
#   'category': 'Salads',
#   'calories': '60',
#   'fat': '2',
#   'carbs': '9',
#   'restaurant': 'Burger King'},
#  {'name': 'BK™ Breakfast Platter',
#   'category': 'Breakfast',
#   'calories': '810',
#   'fat': '54',
#   'carbs': '57',
#   'restaurant': 'Burger King'},
#  {'name': "Double Croissan'wich™ w/ Sausage, Bacon, Egg, & Cheese",
#   'category': 'Breakfast',
#   'calories': '570',
#   'fat': '37',
#   'carbs': '28',
#   'restaurant': 'Burger King'},
#  {'name': 'Side of Eggs',
#   'category': 'Breakfast',
#   'calories': '160',
#   'fat': '12',
#   'carbs': '3',
#   'restaurant': 'Burger King'},
#  {'name': 'Vanilla Icing',
#   'category': 'Breakfast',
#   'calories': '90',
#   'fat': '0',
#   'carbs': '22',
#   'restaurant': 'Burger King'},
#  {'name': 'Biscuit‐ w/ Country Ham (1 sl) & Egg and Cheese',
#   'category': 'Breakfast',
#   'calories': '470',
#   'fat': '26',
#   'carbs': '33',
#   'restaurant': 'Burger King'},
#  {'name': 'Strawberry Sundae',
#   'category': 'Desserts',
#   'calories': '190',
#   'fat': '4',
#   'carbs': '35',
#   'restaurant': 'Burger King'},
#  {'name': 'Vanilla Milk Shake',
#   'category': 'Shakes',
#   'calories': '850',
#   'fat': '20',
#   'carbs': '152',
#   'restaurant': 'Burger King'},
#  {'name': 'BK Toppers™ Mushroom and Swiss',
#   'category': 'Burgers',
#   'calories': '410',
#   'fat': '27',
#   'carbs': '27',
#   'restaurant': 'Burger King'},
#  {'name': 'Whopper® Sandwich with Cheese w/o Mayo',
#   'category': 'Sandwiches',
#   'calories': '600',
#   'fat': '30',
#   'carbs': '53',
#   'restaurant': 'Burger King'},
#  {'name': 'Texas Double Whopper® Sandwich',
#   'category': 'Sandwiches',
#   'calories': '1040',
#   'fat': '69',
#   'carbs': '50',
#   'restaurant': 'Burger King'},
#  {'name': 'Double Cheeseburger',
#   'category': 'Burgers',
#   'calories': '450',
#   'fat': '26',
#   'carbs': '29',
#   'restaurant': 'Burger King'},
#  {'name': 'Tendercrisp® Chicken Sandwich',
#   'category': 'Sandwiches',
#   'calories': '750',
#   'fat': '45',
#   'carbs': '58',
#   'restaurant': 'Burger King'},
#  {'name': 'Chicken Tenders® (6 pc)',
#   'category': 'Chicken',
#   'calories': '290',
#   'fat': '17',
#   'carbs': '15',
#   'restaurant': 'Burger King'},
#  {'name': 'BK Big Fish® Sandwich',
#   'category': 'Sandwiches',
#   'calories': '590',
#   'fat': '31',
#   'carbs': '57',
#   'restaurant': 'Burger King'},
#  {'name': "Motts'® Harvest Plus Applesauce",
#   'category': 'Sides',
#   'calories': '50',
#   'fat': '0',
#   'carbs': '13',
#   'restaurant': 'Burger King'},
#  {'name': 'Tendergrill™ Chicken Garden Salad',
#   'category': 'Salads',
#   'calories': '290',
#   'fat': '12',
#   'carbs': '8',
#   'restaurant': 'Burger King'},
#  {'name': 'Quaker® Oatmeal Maple and Brown Sugar Flavor',
#   'category': 'Breakfast',
#   'calories': '270',
#   'fat': '4',
#   'carbs': '55',
#   'restaurant': 'Burger King'},
#  {'name': 'BK™ Breakfast Ciabatta Club Sandwich',
#   'category': 'Breakfast',
#   'calories': '480',
#   'fat': '23',
#   'carbs': '41',
#   'restaurant': 'Burger King'},
#  {'name': "Double Croissan'wich™ w/ Ham, Bacon, Egg, & Cheese",
#   'category': 'Breakfast',
#   'calories': '440',
#   'fat': '24',
#   'carbs': '28',
#   'restaurant': 'Burger King'},
#  {'name': 'French Toast Sticks (3 piece)',
#   'category': 'Breakfast',
#   'calories': '230',
#   'fat': '11',
#   'carbs': '29',
#   'restaurant': 'Burger King'},
#  {'name': 'BK™ Breakfast Burrito ‐ Sausage, Egg, Cheese & Salsa',
#   'category': 'Breakfast',
#   'calories': '440',
#   'fat': '29',
#   'carbs': '25',
#   'restaurant': 'Burger King'},
#  {'name': 'Peach Granola Sundae',
#   'category': 'Desserts',
#   'calories': '280',
#   'fat': '5',
#   'carbs': '54',
#   'restaurant': 'Burger King'},
#  {'name': 'Chocolate Milk Shake',
#   'category': 'Shakes',
#   'calories': '420',
#   'fat': '8',
#   'carbs': '81',
#   'restaurant': 'Burger King'},
#  {'name': 'Strawberry Swirl Cheesecake',
#   'category': 'Desserts',
#   'calories': '300',
#   'fat': '16',
#   'carbs': '35',
#   'restaurant': 'Burger King'},
#  {'name': 'Double Whopper® Sandwich',
#   'category': 'Sandwiches',
#   'calories': '900',
#   'fat': '57',
#   'carbs': '51',
#   'restaurant': 'Burger King'},
#  {'name': 'Texas Triple Whopper® Sandwich',
#   'category': 'Sandwiches',
#   'calories': '1270',
#   'fat': '86',
#   'carbs': '50',
#   'restaurant': 'Burger King'},
#  {'name': 'Rodeo Cheeseburger',
#   'category': 'Burgers',
#   'calories': '350',
#   'fat': '17',
#   'carbs': '37',
#   'restaurant': 'Burger King'},
#  {'name': 'Tendercrisp® Chicken Sandwich w/o Mayo',
#   'category': 'Sandwiches',
#   'calories': '540',
#   'fat': '21',
#   'carbs': '57',
#   'restaurant': 'Burger King'},
#  {'name': 'Chicken Tenders® (8 pc)',
#   'category': 'Chicken',
#   'calories': '380',
#   'fat': '22',
#   'carbs': '20',
#   'restaurant': 'Burger King'},
#  {'name': 'BK Big Fish® Sandwich w/o Tartar Sauce',
#   'category': 'Sandwiches',
#   'calories': '410',
#   'fat': '12',
#   'carbs': '53',
#   'restaurant': 'Burger King'},
#  {'name': 'Onion Rings - value',
#   'category': 'Sides',
#   'calories': '150',
#   'fat': '8',
#   'carbs': '17',
#   'restaurant': 'Burger King'},
#  {'name': 'Tendercrisp® Chicken Garden Salad',
#   'category': 'Salads',
#   'calories': '470',
#   'fat': '26',
#   'carbs': '26',
#   'restaurant': 'Burger King'},
#  {'name': 'Enormous Omelet Sandwich',
#   'category': 'Breakfast',
#   'calories': '760',
#   'fat': '44',
#   'carbs': '44',
#   'restaurant': 'Burger King'},
#  {'name': "Double Croissan'wich™ w/ Ham, Sausage, Egg, & Cheese",
#   'category': 'Breakfast',
#   'calories': '570',
#   'fat': '35',
#   'carbs': '28',
#   'restaurant': 'Burger King'},
#  {'name': 'French Toast Sticks (5 piece)',
#   'category': 'Breakfast',
#   'calories': '380',
#   'fat': '18',
#   'carbs': '49',
#   'restaurant': 'Burger King'},
#  {'name': 'BK™ Breakfast Burrito ‐ Potato, Egg, Cheese, & Salsa',
#   'category': 'Breakfast',
#   'calories': '320',
#   'fat': '17',
#   'carbs': '29',
#   'restaurant': 'Burger King'},
#  {'name': 'Oreo® Sundae',
#   'category': 'Desserts',
#   'calories': '440',
#   'fat': '12',
#   'carbs': '77',
#   'restaurant': 'Burger King'},
#  {'name': 'Chocolate Milk Shake',
#   'category': 'Shakes',
#   'calories': '690',
#   'fat': '18',
#   'carbs': '121',
#   'restaurant': 'Burger King'},
#  {'name': 'Fanta Cherry frozen concentrated beverage',
#   'category': 'Drinks',
#   'calories': '110',
#   'fat': '0',
#   'carbs': '31',
#   'restaurant': 'Burger King'},
#  {'name': 'Bite Size Shrimp',
#   'category': 'Entrees',
#   'calories': '460',
#   'fat': '21',
#   'carbs': '51',
#   'restaurant': "Captain D's"},
#  {'name': 'Chicken Ranch Sandwich',
#   'category': 'Sandwiches',
#   'calories': '680',
#   'fat': '33',
#   'carbs': '69',
#   'restaurant': "Captain D's"},
#  {'name': 'Roasted Red Potatoes',
#   'category': 'Sides',
#   'calories': '170',
#   'fat': '7',
#   'carbs': '25',
#   'restaurant': "Captain D's"},
#  {'name': 'Fried Okra',
#   'category': 'Sides',
#   'calories': '230',
#   'fat': '14',
#   'carbs': '23',
#   'restaurant': "Captain D's"},
#  {'name': 'Pineapple Cream Cheese Pie',
#   'category': 'Desserts',
#   'calories': '320',
#   'fat': '14',
#   'carbs': '43',
#   'restaurant': "Captain D's"},
#  {'name': 'Batter‐Dipped Fish',
#   'category': 'Entrees',
#   'calories': '182',
#   'fat': '12',
#   'carbs': '8',
#   'restaurant': "Captain D's"},
#  {'name': 'Coconut Shrimp',
#   'category': 'Entrees',
#   'calories': '321',
#   'fat': '19',
#   'carbs': '27',
#   'restaurant': "Captain D's"},
#  {'name': 'Wild Alaskan Salmon Sandwich',
#   'category': 'Sandwiches',
#   'calories': '520',
#   'fat': '18',
#   'carbs': '48',
#   'restaurant': "Captain D's"},
#  {'name': 'Hush Puppies (2)',
#   'category': 'Sides',
#   'calories': '200',
#   'fat': '13',
#   'carbs': '18',
#   'restaurant': "Captain D's"},
#  {'name': 'Ginger Teriyaki Sauce',
#   'category': 'Sides',
#   'calories': '60',
#   'fat': '0',
#   'carbs': '13',
#   'restaurant': "Captain D's"},
#  {'name': 'Country Style Fish',
#   'category': 'Entrees',
#   'calories': '195',
#   'fat': '10',
#   'carbs': '14',
#   'restaurant': "Captain D's"},
#  {'name': 'Stuffed Crab Shell',
#   'category': 'Entrees',
#   'calories': '100',
#   'fat': '5',
#   'carbs': '9',
#   'restaurant': "Captain D's"},
#  {'name': 'Wild Alaskan Salmon Salad',
#   'category': 'Salads',
#   'calories': '177',
#   'fat': '1',
#   'carbs': '8',
#   'restaurant': "Captain D's"},
#  {'name': 'Cracklins',
#   'category': 'Sides',
#   'calories': '160',
#   'fat': '12',
#   'carbs': '11',
#   'restaurant': "Captain D's"},
#  {'name': 'Scampi Butter Sauce',
#   'category': 'Sides',
#   'calories': '120',
#   'fat': '10',
#   'carbs': '5',
#   'restaurant': "Captain D's"},
#  {'name': 'Seasoned Tilapia',
#   'category': 'Entrees',
#   'calories': '130',
#   'fat': '3',
#   'carbs': '1',
#   'restaurant': "Captain D's"},
#  {'name': 'Chicken Tender',
#   'category': 'Entrees',
#   'calories': '170',
#   'fat': '10',
#   'carbs': '11',
#   'restaurant': "Captain D's"},
#  {'name': 'Side Salad',
#   'category': 'Sides',
#   'calories': '14',
#   'fat': '0',
#   'carbs': '2',
#   'restaurant': "Captain D's"},
#  {'name': 'Breadstick',
#   'category': 'Sides',
#   'calories': '150',
#   'fat': '6',
#   'carbs': '21',
#   'restaurant': "Captain D's"},
#  {'name': 'Chocolate Cake',
#   'category': 'Desserts',
#   'calories': '300',
#   'fat': '11',
#   'carbs': '49',
#   'restaurant': "Captain D's"},
#  {'name': 'Premium Shrimp',
#   'category': 'Entrees',
#   'calories': '154',
#   'fat': '6',
#   'carbs': '0',
#   'restaurant': "Captain D's"},
#  {'name': 'Great Little Fish Sandwich',
#   'category': 'Sandwiches',
#   'calories': '642',
#   'fat': '38',
#   'carbs': '56',
#   'restaurant': "Captain D's"},
#  {'name': 'French Fries',
#   'category': 'Sides',
#   'calories': '310',
#   'fat': '15',
#   'carbs': '38',
#   'restaurant': "Captain D's"},
#  {'name': 'Seasoned Rice',
#   'category': 'Sides',
#   'calories': '160',
#   'fat': '1',
#   'carbs': '35',
#   'restaurant': "Captain D's"},
#  {'name': 'Cheesecake',
#   'category': 'Desserts',
#   'calories': '410',
#   'fat': '27',
#   'carbs': '35',
#   'restaurant': "Captain D's"},
#  {'name': 'Shrimp Skewers',
#   'category': 'Entrees',
#   'calories': '50',
#   'fat': '0',
#   'carbs': '0',
#   'restaurant': "Captain D's"},
#  {'name': 'Classic Fish Sandwich',
#   'category': 'Sandwiches',
#   'calories': '744',
#   'fat': '41',
#   'carbs': '63',
#   'restaurant': "Captain D's"},
#  {'name': 'Macaroni & Cheese',
#   'category': 'Sides',
#   'calories': '160',
#   'fat': '7',
#   'carbs': '17',
#   'restaurant': "Captain D's"},
#  {'name': 'Jalapeno Poppers',
#   'category': 'Sides',
#   'calories': '155',
#   'fat': '7',
#   'carbs': '20',
#   'restaurant': "Captain D's"},
#  {'name': 'Pecan Pie',
#   'category': 'Desserts',
#   'calories': '470',
#   'fat': '26',
#   'carbs': '56',
#   'restaurant': "Captain D's"},
#  {'name': 'Scampi Shrimp',
#   'category': 'Entrees',
#   'calories': '28',
#   'fat': '0',
#   'carbs': '0',
#   'restaurant': "Captain D's"},
#  {'name': 'The Captain',
#   'category': 'Sandwiches',
#   'calories': '1008',
#   'fat': '50',
#   'carbs': '81',
#   'restaurant': "Captain D's"},
#  {'name': 'Cole Slaw',
#   'category': 'Sides',
#   'calories': '170',
#   'fat': '12',
#   'carbs': '13',
#   'restaurant': "Captain D's"},
#  {'name': 'Cheese Sticks',
#   'category': 'Sides',
#   'calories': '220',
#   'fat': '12',
#   'carbs': '16',
#   'restaurant': "Captain D's"},
#  {'name': 'Cheesecake with Strawberries',
#   'category': 'Desserts',
#   'calories': '430',
#   'fat': '26',
#   'carbs': '45',
#   'restaurant': "Captain D's"},
#  {'name': 'Fried Flounder',
#   'category': 'Entrees',
#   'calories': '213',
#   'fat': '13',
#   'carbs': '12',
#   'restaurant': "Captain D's"},
#  {'name': 'Oysters',
#   'category': 'Entrees',
#   'calories': '320',
#   'fat': '18',
#   'carbs': '31',
#   'restaurant': "Captain D's"},
#  {'name': 'Bite Size Shrimp Salad',
#   'category': 'Salads',
#   'calories': '267',
#   'fat': '10',
#   'carbs': '33',
#   'restaurant': "Captain D's"},
#  {'name': 'Corn on the Cob',
#   'category': 'Sides',
#   'calories': '190',
#   'fat': '2',
#   'carbs': '37',
#   'restaurant': "Captain D's"},
#  {'name': 'Sweet Chili Sauce',
#   'category': 'Sides',
#   'calories': '100',
#   'fat': '0',
#   'carbs': '25',
#   'restaurant': "Captain D's"},
#  {'name': 'Catfish',
#   'category': 'Entrees',
#   'calories': '105',
#   'fat': '6',
#   'carbs': '6',
#   'restaurant': "Captain D's"},
#  {'name': '1/2 LB Clams',
#   'category': 'Entrees',
#   'calories': '770',
#   'fat': '47',
#   'carbs': '64',
#   'restaurant': "Captain D's"},
#  {'name': 'Fried Chicken Salad',
#   'category': 'Salads',
#   'calories': '207',
#   'fat': '10',
#   'carbs': '18',
#   'restaurant': "Captain D's"},
#  ...]

# %% [markdown]
# ### Step 4: Create a pandas DataFrame from your list of foods
#
# **Note**: Your DataFrame should have 5,131 rows

# %%
df = pd.DataFrame(foods)
df.head()
# Out:
#                                  name      category calories fat carbs  \
# 0  Original Bacon Double Cheeseburger       Burgers      760  45    45
# 1                   Coney (Chili) Dog       Entrees      340  20    26
# 2                         Chili Fries  French Fries      370  15    49
# 3        Strawberry Milkshake (small)        Shakes      670  29    90
# 4       A&W® Root Beer Freeze (large)        Shakes      820  18   150
#
#         restaurant
# 0  A&W Restaurants
# 1  A&W Restaurants
# 2  A&W Restaurants
# 3  A&W Restaurants
# 4  A&W Restaurants

# %%
df.tail()
# Out:
#                                 name    category calories fat carbs restaurant
# 5126  Jr. Original Chocolate Frosty™      Shakes      200   5    32    Wendy's
# 5127         Grilled Chicken Go Wrap       Wraps      260  10    25    Wendy's
# 5128       Asiago Ranch Chicken Club  Sandwiches      670  32    57    Wendy's
# 5129           Spicy Chicken Go Wrap       Wraps      330  16    30    Wendy's
# 5130  Large Strawberry Frosty™ Shake      Shakes      780  15   149    Wendy's

# %%
len(df)
# Out:
# 5131

# %% [markdown]
# ### Step 5: Export to csv
#
# **Note:** Don't export the index column from your DataFrame

# %%
df.to_csv('scrapped_data.csv', index=False)
